# %% [markdown]
# # Features
#
# This notebook creates features for the raw data.

# %% [markdown]
# ## Weather Features
#
# Add features like temperature, humidity, sun hours, ...

# %% [markdown]
# Start with the daily data

# %%
import holidays.countries
import polars as pl

from src.energy_forecast.config import RAW_DATA_DIR

data_df = pl.read_csv(RAW_DATA_DIR / "daily.csv").with_columns(pl.col("date").str.to_datetime())
data_df
# Out:
# 2025-02-04 11:57:41.684 | INFO     | src.energy_forecast.config:<module>:11 - PROJ_ROOT path is: /home/marja/PycharmProjects/energy-forecast-wahl
# shape: (59_790, 8)
# ┌──────────────┬──────────────┬────────┬──────────────┬─────────────┬─────────────┬───────┬────────┐
# │ id           ┆ date         ┆ diff   ┆ primary_ener ┆ adresse     ┆ ort         ┆ plz   ┆ source │
# │ ---          ┆ ---          ┆ ---    ┆ gy           ┆ ---         ┆ ---         ┆ ---   ┆ ---    │
# │ str          ┆ datetime[μs] ┆ f64    ┆ ---          ┆ str         ┆ str         ┆ i64   ┆ str    │
# │              ┆              ┆        ┆ str          ┆             ┆             ┆       ┆        │
# ╞══════════════╪══════════════╪════════╪══════════════╪═════════════╪═════════════╪═══════╪════════╡
# │ 0c9ad311-b86 ┆ 2022-10-01   ┆ 703.0  ┆ district     ┆ Kielortring ┆ Norderstedt ┆ 22850 ┆ dh     │
# │ f-4371-a695- ┆ 00:00:00     ┆        ┆ heating      ┆ 14          ┆             ┆       ┆        │
# │ 512ca4…      ┆              ┆        ┆              ┆             ┆             ┆       ┆        │
# │ 0c9ad311-b86 ┆ 2022-10-02   ┆ 334.0  ┆ district     ┆ Kielortring ┆ Norderstedt ┆ 22850 ┆ dh     │
# │ f-4371-a695- ┆ 00:00:00     ┆        ┆ heating      ┆ 14          ┆             ┆       ┆        │
# │ 512ca4…      ┆              ┆        ┆              ┆             ┆             ┆       ┆        │
# │ 0c9ad311-b86 ┆ 2022-10-03   ┆ 891.0  ┆ district     ┆ Kielortring ┆ Norderstedt ┆ 22850 ┆ dh     │
# │ f-4371-a695- ┆ 00:00:00     ┆        ┆ heating      ┆ 14          ┆             ┆       ┆        │
# │ 512ca4…      ┆              ┆        ┆              ┆             ┆             ┆       ┆        │
# │ 0c9ad311-b86 ┆ 2022-10-04   ┆ 661.0  ┆ district     ┆ Kielortring ┆ Norderstedt ┆ 22850 ┆ dh     │
# │ f-4371-a695- ┆ 00:00:00     ┆        ┆ heating      ┆ 14          ┆             ┆       ┆        │
# │ 512ca4…      ┆              ┆        ┆              ┆             ┆             ┆       ┆        │
# │ 0c9ad311-b86 ┆ 2022-10-05   ┆ 499.0  ┆ district     ┆ Kielortring ┆ Norderstedt ┆ 22850 ┆ dh     │
# │ f-4371-a695- ┆ 00:00:00     ┆        ┆ heating      ┆ 14          ┆             ┆       ┆        │
# │ 512ca4…      ┆              ┆        ┆              ┆             ┆             ┆       ┆        │
# │ …            ┆ …            ┆ …      ┆ …            ┆ …           ┆ …           ┆ …     ┆ …      │
# │ 4008231VG    ┆ 2022-03-11   ┆ 1435.1 ┆ gas          ┆ Tinnumer    ┆ Hamburg     ┆ 22117 ┆ legacy │
# │              ┆ 00:00:00     ┆        ┆              ┆ Weg 1-9,    ┆             ┆       ┆        │
# │              ┆              ┆        ┆              ┆ Morsumer    ┆             ┆       ┆        │
# │              ┆              ┆        ┆              ┆ Weg…        ┆             ┆       ┆        │
# │ 4008231VG    ┆ 2022-03-12   ┆ 1083.3 ┆ gas          ┆ Tinnumer    ┆ Hamburg     ┆ 22117 ┆ legacy │
# │              ┆ 00:00:00     ┆        ┆              ┆ Weg 1-9,    ┆             ┆       ┆        │
# │              ┆              ┆        ┆              ┆ Morsumer    ┆             ┆       ┆        │
# │              ┆              ┆        ┆              ┆ Weg…        ┆             ┆       ┆        │
# │ 4008231VG    ┆ 2022-03-13   ┆ 1038.4 ┆ gas          ┆ Tinnumer    ┆ Hamburg     ┆ 22117 ┆ legacy │
# │              ┆ 00:00:00     ┆        ┆              ┆ Weg 1-9,    ┆             ┆       ┆        │
# │              ┆              ┆        ┆              ┆ Morsumer    ┆             ┆       ┆        │
# │              ┆              ┆        ┆              ┆ Weg…        ┆             ┆       ┆        │
# │ 4008231VG    ┆ 2022-03-14   ┆ 996.6  ┆ gas          ┆ Tinnumer    ┆ Hamburg     ┆ 22117 ┆ legacy │
# │              ┆ 00:00:00     ┆        ┆              ┆ Weg 1-9,    ┆             ┆       ┆        │
# │              ┆              ┆        ┆              ┆ Morsumer    ┆             ┆       ┆        │
# │              ┆              ┆        ┆              ┆ Weg…        ┆             ┆       ┆        │
# │ 4008231VG    ┆ 2022-03-15   ┆ 495.5  ┆ gas          ┆ Tinnumer    ┆ Hamburg     ┆ 22117 ┆ legacy │
# │              ┆ 00:00:00     ┆        ┆              ┆ Weg 1-9,    ┆             ┆       ┆        │
# │              ┆              ┆        ┆              ┆ Morsumer    ┆             ┆       ┆        │
# │              ┆              ┆        ┆              ┆ Weg…        ┆             ┆       ┆        │
# └──────────────┴──────────────┴────────┴──────────────┴─────────────┴─────────────┴───────┴────────┘

# %% [markdown]
# Find time intervals for every city

# %%
city_df = data_df.group_by(pl.col("ort"), pl.col("plz")).agg(pl.col("date").min().alias("min_date"),
                                                             pl.col("date").max().alias("max_date"))
city_df
# Out:
# shape: (36, 4)
# ┌──────────────┬───────┬─────────────────────┬─────────────────────┐
# │ ort          ┆ plz   ┆ min_date            ┆ max_date            │
# │ ---          ┆ ---   ┆ ---                 ┆ ---                 │
# │ str          ┆ i64   ┆ datetime[μs]        ┆ datetime[μs]        │
# ╞══════════════╪═══════╪═════════════════════╪═════════════════════╡
# │ Norderstedt  ┆ 22850 ┆ 2022-10-01 00:00:00 ┆ 2024-05-14 00:00:00 │
# │ Hamburg      ┆ 20539 ┆ 2022-01-24 00:00:00 ┆ 2023-09-21 00:00:00 │
# │ Norderstedt  ┆ 22844 ┆ 2022-08-24 00:00:00 ┆ 2024-05-14 00:00:00 │
# │ Elmshorn     ┆ 25336 ┆ 2018-12-14 00:00:00 ┆ 2022-04-04 00:00:00 │
# │ Norderstedt  ┆ 22846 ┆ 2022-08-24 00:00:00 ┆ 2024-05-14 00:00:00 │
# │ …            ┆ …     ┆ …                   ┆ …                   │
# │ Tangstedt    ┆ 22889 ┆ 2018-02-01 00:00:00 ┆ 2022-04-04 00:00:00 │
# │ Schwarzenbek ┆ 21493 ┆ 2018-02-24 00:00:00 ┆ 2022-04-04 00:00:00 │
# │ Großhansdorf ┆ 22927 ┆ 2018-02-09 00:00:00 ┆ 2020-11-23 00:00:00 │
# │ Hamburg      ┆ 22547 ┆ 2017-09-21 00:00:00 ┆ 2022-03-16 00:00:00 │
# │ Hamburg      ┆ 21077 ┆ 2022-08-31 00:00:00 ┆ 2023-09-25 00:00:00 │
# └──────────────┴───────┴─────────────────────┴─────────────────────┘

# %% [markdown]
# Add coordinates to every city

# %%
import pgeocode

city_df = city_df.with_columns(
    pl.col("plz").map_elements(lambda x: pgeocode.Nominatim("de").query_postal_code(str(x))["latitude"]).alias("lat"),
    pl.col("plz").map_elements(lambda x: pgeocode.Nominatim("de").query_postal_code(str(x))["longitude"]).alias("lon"),
    pl.col("plz").map_elements(lambda x: pgeocode.Nominatim("de").query_postal_code(str(x))["state_code"]).alias(
        "state"),
)
city_df
# Out:
# sys:1: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
# sys:1: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
# sys:1: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
# shape: (36, 7)
# ┌──────────────┬───────┬─────────────────────┬─────────────────────┬───────────┬───────────┬───────┐
# │ ort          ┆ plz   ┆ min_date            ┆ max_date            ┆ lat       ┆ lon       ┆ state │
# │ ---          ┆ ---   ┆ ---                 ┆ ---                 ┆ ---       ┆ ---       ┆ ---   │
# │ str          ┆ i64   ┆ datetime[μs]        ┆ datetime[μs]        ┆ f64       ┆ f64       ┆ str   │
# ╞══════════════╪═══════╪═════════════════════╪═════════════════════╪═══════════╪═══════════╪═══════╡
# │ Norderstedt  ┆ 22850 ┆ 2022-10-01 00:00:00 ┆ 2024-05-14 00:00:00 ┆ 53.6855   ┆ 9.9976    ┆ SH    │
# │ Hamburg      ┆ 20539 ┆ 2022-01-24 00:00:00 ┆ 2023-09-21 00:00:00 ┆ 53.52602  ┆ 10.02002  ┆ HH    │
# │ Norderstedt  ┆ 22844 ┆ 2022-08-24 00:00:00 ┆ 2024-05-14 00:00:00 ┆ 53.7246   ┆ 10.0124   ┆ SH    │
# │ Elmshorn     ┆ 25336 ┆ 2018-12-14 00:00:00 ┆ 2022-04-04 00:00:00 ┆ 53.73565  ┆ 9.6567    ┆ SH    │
# │ Norderstedt  ┆ 22846 ┆ 2022-08-24 00:00:00 ┆ 2024-05-14 00:00:00 ┆ 53.7099   ┆ 9.9946    ┆ SH    │
# │ …            ┆ …     ┆ …                   ┆ …                   ┆ …         ┆ …         ┆ …     │
# │ Tangstedt    ┆ 22889 ┆ 2018-02-01 00:00:00 ┆ 2022-04-04 00:00:00 ┆ 53.7333   ┆ 10.0833   ┆ SH    │
# │ Schwarzenbek ┆ 21493 ┆ 2018-02-24 00:00:00 ┆ 2022-04-04 00:00:00 ┆ 53.551392 ┆ 10.510546 ┆ SH    │
# │ Großhansdorf ┆ 22927 ┆ 2018-02-09 00:00:00 ┆ 2020-11-23 00:00:00 ┆ 53.6667   ┆ 10.2833   ┆ SH    │
# │ Hamburg      ┆ 22547 ┆ 2017-09-21 00:00:00 ┆ 2022-03-16 00:00:00 ┆ 53.58628  ┆ 9.88696   ┆ HH    │
# │ Hamburg      ┆ 21077 ┆ 2022-08-31 00:00:00 ┆ 2023-09-25 00:00:00 ┆ 53.435371 ┆ 9.973929  ┆ HH    │
# └──────────────┴───────┴─────────────────────┴─────────────────────┴───────────┴───────────┴───────┘

# %%
from meteostat import Point, Daily

weather_dfs = list()
for row in city_df.iter_rows():
    start = row[2]
    end = row[3]
    loc = Point(row[4], row[5])

    data = Daily(loc, start, end)
    data = data.fetch()
    weather_dfs.append(pl.from_pandas(data.reset_index()).with_columns(pl.lit(row[1]).alias("plz")))
weather_df = pl.concat(weather_dfs)
weather_df
# Out:
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# shape: (31_249, 12)
# ┌─────────────────────┬──────┬──────┬──────┬───┬──────┬────────┬───────┬───────┐
# │ time                ┆ tavg ┆ tmin ┆ tmax ┆ … ┆ wpgt ┆ pres   ┆ tsun  ┆ plz   │
# │ ---                 ┆ ---  ┆ ---  ┆ ---  ┆   ┆ ---  ┆ ---    ┆ ---   ┆ ---   │
# │ datetime[ns]        ┆ f64  ┆ f64  ┆ f64  ┆   ┆ f64  ┆ f64    ┆ f64   ┆ i32   │
# ╞═════════════════════╪══════╪══════╪══════╪═══╪══════╪════════╪═══════╪═══════╡
# │ 2022-10-01 00:00:00 ┆ 11.8 ┆ 9.6  ┆ 15.9 ┆ … ┆ 58.0 ┆ 1003.3 ┆ 156.0 ┆ 22850 │
# │ 2022-10-02 00:00:00 ┆ 12.4 ┆ 9.3  ┆ 16.4 ┆ … ┆ 45.7 ┆ 1013.8 ┆ 318.0 ┆ 22850 │
# │ 2022-10-03 00:00:00 ┆ 12.7 ┆ 8.1  ┆ 16.2 ┆ … ┆ 45.7 ┆ 1023.0 ┆ 138.0 ┆ 22850 │
# │ 2022-10-04 00:00:00 ┆ 12.9 ┆ 8.8  ┆ 17.8 ┆ … ┆ 35.3 ┆ 1019.8 ┆ 354.0 ┆ 22850 │
# │ 2022-10-05 00:00:00 ┆ 15.3 ┆ 12.3 ┆ 17.6 ┆ … ┆ 58.0 ┆ 1013.9 ┆ 0.0   ┆ 22850 │
# │ …                   ┆ …    ┆ …    ┆ …    ┆ … ┆ …    ┆ …      ┆ …     ┆ …     │
# │ 2023-09-21 00:00:00 ┆ 20.3 ┆ 16.8 ┆ 26.7 ┆ … ┆ 37.4 ┆ 1000.0 ┆ 378.0 ┆ 21077 │
# │ 2023-09-22 00:00:00 ┆ 15.8 ┆ 10.4 ┆ 20.0 ┆ … ┆ 37.1 ┆ 1000.3 ┆ 240.0 ┆ 21077 │
# │ 2023-09-23 00:00:00 ┆ 13.8 ┆ 11.1 ┆ 17.6 ┆ … ┆ 39.2 ┆ 1010.6 ┆ 162.0 ┆ 21077 │
# │ 2023-09-24 00:00:00 ┆ 13.2 ┆ 7.7  ┆ 18.7 ┆ … ┆ 26.6 ┆ 1024.6 ┆ 540.0 ┆ 21077 │
# │ 2023-09-25 00:00:00 ┆ 14.8 ┆ 9.0  ┆ 21.2 ┆ … ┆ 32.4 ┆ 1024.4 ┆ 474.0 ┆ 21077 │
# └─────────────────────┴──────┴──────┴──────┴───┴──────┴────────┴───────┴───────┘

# %% [markdown]
# Merge with data

# %%
data_df.with_columns(pl.col("date").dt.date()).join(weather_df.with_columns(pl.col("time").dt.date().alias("date")),
                                                    on=["plz", 'date'], how="left")
# Out:
# shape: (59_790, 19)
# ┌──────────────────────┬────────────┬────────┬──────────────────┬───┬──────┬──────┬────────┬───────┐
# │ id                   ┆ date       ┆ diff   ┆ primary_energy   ┆ … ┆ wspd ┆ wpgt ┆ pres   ┆ tsun  │
# │ ---                  ┆ ---        ┆ ---    ┆ ---              ┆   ┆ ---  ┆ ---  ┆ ---    ┆ ---   │
# │ str                  ┆ date       ┆ f64    ┆ str              ┆   ┆ f64  ┆ f64  ┆ f64    ┆ f64   │
# ╞══════════════════════╪════════════╪════════╪══════════════════╪═══╪══════╪══════╪════════╪═══════╡
# │ 0c9ad311-b86f-4371-a ┆ 2022-10-01 ┆ 703.0  ┆ district heating ┆ … ┆ 18.7 ┆ 58.0 ┆ 1003.3 ┆ 156.0 │
# │ 695-512ca4…          ┆            ┆        ┆                  ┆   ┆      ┆      ┆        ┆       │
# │ 0c9ad311-b86f-4371-a ┆ 2022-10-02 ┆ 334.0  ┆ district heating ┆ … ┆ 15.1 ┆ 45.7 ┆ 1013.8 ┆ 318.0 │
# │ 695-512ca4…          ┆            ┆        ┆                  ┆   ┆      ┆      ┆        ┆       │
# │ 0c9ad311-b86f-4371-a ┆ 2022-10-03 ┆ 891.0  ┆ district heating ┆ … ┆ 13.7 ┆ 45.7 ┆ 1023.0 ┆ 138.0 │
# │ 695-512ca4…          ┆            ┆        ┆                  ┆   ┆      ┆      ┆        ┆       │
# │ 0c9ad311-b86f-4371-a ┆ 2022-10-04 ┆ 661.0  ┆ district heating ┆ … ┆ 11.5 ┆ 35.3 ┆ 1019.8 ┆ 354.0 │
# │ 695-512ca4…          ┆            ┆        ┆                  ┆   ┆      ┆      ┆        ┆       │
# │ 0c9ad311-b86f-4371-a ┆ 2022-10-05 ┆ 499.0  ┆ district heating ┆ … ┆ 22.7 ┆ 58.0 ┆ 1013.9 ┆ 0.0   │
# │ 695-512ca4…          ┆            ┆        ┆                  ┆   ┆      ┆      ┆        ┆       │
# │ …                    ┆ …          ┆ …      ┆ …                ┆ … ┆ …    ┆ …    ┆ …      ┆ …     │
# │ 4008231VG            ┆ 2022-03-11 ┆ 1435.1 ┆ gas              ┆ … ┆ 30.2 ┆ 58.0 ┆ 1023.9 ┆ 636.0 │
# │ 4008231VG            ┆ 2022-03-12 ┆ 1083.3 ┆ gas              ┆ … ┆ 23.4 ┆ 54.4 ┆ 1021.4 ┆ 594.0 │
# │ 4008231VG            ┆ 2022-03-13 ┆ 1038.4 ┆ gas              ┆ … ┆ 19.1 ┆ 38.9 ┆ 1019.6 ┆ 654.0 │
# │ 4008231VG            ┆ 2022-03-14 ┆ 996.6  ┆ gas              ┆ … ┆ 11.2 ┆ 25.9 ┆ 1023.9 ┆ 240.0 │
# │ 4008231VG            ┆ 2022-03-15 ┆ 495.5  ┆ gas              ┆ … ┆ 5.8  ┆ 18.4 ┆ 1026.9 ┆ 0.0   │
# └──────────────────────┴────────────┴────────┴──────────────────┴───┴──────┴──────┴────────┴───────┘

# %% [markdown]
# From the [meteostat](https://dev.meteostat.net/python/daily.html#api) documentation:
#
# Column	Description	Type
#
# station	The Meteostat ID of the weather station (only if query refers to multiple stations)	String
#
# time	The date	Datetime64
#
# tavg	The average air temperature in °C	Float64
#
# tmin	The minimum air temperature in °C	Float64
#
# tmax	The maximum air temperature in °C	Float64
#
# prcp	The daily precipitation total in mm	Float64
#
# snow	The snow depth in mm	Float64
#
# wdir	The average wind direction in degrees (°)	Float64
#
# wspd	The average wind speed in km/h	Float64
#
# wpgt	The peak wind gust in km/h	Float64
#
# pres	The average sea-level air pressure in hPa	Float64
#
# tsun	The daily sunshine total in minutes (m)	Float64

# %% [markdown]
# Humidity is missing from Daily-data, we can retrieve hourly data and merge to daily data

# %%
from meteostat import Point, Hourly

weather_dfs = list()
for row in city_df.iter_rows():
    start = row[2]
    end = row[3]
    loc = Point(row[4], row[5])

    data = Hourly(loc, start, end)
    data = data.fetch()
    weather_dfs.append(pl.from_pandas(data.reset_index()).group_by_dynamic(
        index_column="time", every="1d"
    ).agg(pl.col("rhum").mean().alias("hum_avg"),
          pl.col("rhum").min().alias("hum_min"),
          pl.col("rhum").max().alias("hum_max")
          ).with_columns(pl.lit(row[1]).alias("plz")))
weather_df_hourly = pl.concat(weather_dfs)
weather_df_hourly
# Out:
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# shape: (31_249, 5)
# ┌─────────────────────┬───────────┬─────────┬─────────┬───────┐
# │ time                ┆ hum_avg   ┆ hum_min ┆ hum_max ┆ plz   │
# │ ---                 ┆ ---       ┆ ---     ┆ ---     ┆ ---   │
# │ datetime[ns]        ┆ f64       ┆ f64     ┆ f64     ┆ i32   │
# ╞═════════════════════╪═══════════╪═════════╪═════════╪═══════╡
# │ 2022-10-01 00:00:00 ┆ 85.666667 ┆ 73.0    ┆ 96.0    ┆ 22850 │
# │ 2022-10-02 00:00:00 ┆ 86.333333 ┆ 66.0    ┆ 96.0    ┆ 22850 │
# │ 2022-10-03 00:00:00 ┆ 88.333333 ┆ 74.0    ┆ 97.0    ┆ 22850 │
# │ 2022-10-04 00:00:00 ┆ 83.0      ┆ 59.0    ┆ 100.0   ┆ 22850 │
# │ 2022-10-05 00:00:00 ┆ 74.833333 ┆ 68.0    ┆ 81.0    ┆ 22850 │
# │ …                   ┆ …         ┆ …       ┆ …       ┆ …     │
# │ 2023-09-21 00:00:00 ┆ 69.375    ┆ 44.0    ┆ 94.0    ┆ 21077 │
# │ 2023-09-22 00:00:00 ┆ 79.291667 ┆ 56.0    ┆ 95.0    ┆ 21077 │
# │ 2023-09-23 00:00:00 ┆ 85.833333 ┆ 65.0    ┆ 97.0    ┆ 21077 │
# │ 2023-09-24 00:00:00 ┆ 85.5      ┆ 60.0    ┆ 99.0    ┆ 21077 │
# │ 2023-09-25 00:00:00 ┆ 84.0      ┆ 84.0    ┆ 84.0    ┆ 21077 │
# └─────────────────────┴───────────┴─────────┴─────────┴───────┘

# %% [markdown]
# Add to other weather data

# %%
weather_df = weather_df_hourly.join(weather_df, on=["plz", 'time'], how="left")
weather_df
# Out:
# shape: (31_249, 15)
# ┌─────────────────────┬───────────┬─────────┬─────────┬───┬──────┬──────┬────────┬───────┐
# │ time                ┆ hum_avg   ┆ hum_min ┆ hum_max ┆ … ┆ wspd ┆ wpgt ┆ pres   ┆ tsun  │
# │ ---                 ┆ ---       ┆ ---     ┆ ---     ┆   ┆ ---  ┆ ---  ┆ ---    ┆ ---   │
# │ datetime[ns]        ┆ f64       ┆ f64     ┆ f64     ┆   ┆ f64  ┆ f64  ┆ f64    ┆ f64   │
# ╞═════════════════════╪═══════════╪═════════╪═════════╪═══╪══════╪══════╪════════╪═══════╡
# │ 2022-10-01 00:00:00 ┆ 85.666667 ┆ 73.0    ┆ 96.0    ┆ … ┆ 18.7 ┆ 58.0 ┆ 1003.3 ┆ 156.0 │
# │ 2022-10-02 00:00:00 ┆ 86.333333 ┆ 66.0    ┆ 96.0    ┆ … ┆ 15.1 ┆ 45.7 ┆ 1013.8 ┆ 318.0 │
# │ 2022-10-03 00:00:00 ┆ 88.333333 ┆ 74.0    ┆ 97.0    ┆ … ┆ 13.7 ┆ 45.7 ┆ 1023.0 ┆ 138.0 │
# │ 2022-10-04 00:00:00 ┆ 83.0      ┆ 59.0    ┆ 100.0   ┆ … ┆ 11.5 ┆ 35.3 ┆ 1019.8 ┆ 354.0 │
# │ 2022-10-05 00:00:00 ┆ 74.833333 ┆ 68.0    ┆ 81.0    ┆ … ┆ 22.7 ┆ 58.0 ┆ 1013.9 ┆ 0.0   │
# │ …                   ┆ …         ┆ …       ┆ …       ┆ … ┆ …    ┆ …    ┆ …      ┆ …     │
# │ 2023-09-21 00:00:00 ┆ 69.375    ┆ 44.0    ┆ 94.0    ┆ … ┆ 14.1 ┆ 37.4 ┆ 1000.0 ┆ 378.0 │
# │ 2023-09-22 00:00:00 ┆ 79.291667 ┆ 56.0    ┆ 95.0    ┆ … ┆ 12.3 ┆ 37.1 ┆ 1000.3 ┆ 240.0 │
# │ 2023-09-23 00:00:00 ┆ 85.833333 ┆ 65.0    ┆ 97.0    ┆ … ┆ 13.7 ┆ 39.2 ┆ 1010.6 ┆ 162.0 │
# │ 2023-09-24 00:00:00 ┆ 85.5      ┆ 60.0    ┆ 99.0    ┆ … ┆ 8.0  ┆ 26.6 ┆ 1024.6 ┆ 540.0 │
# │ 2023-09-25 00:00:00 ┆ 84.0      ┆ 84.0    ┆ 84.0    ┆ … ┆ 10.9 ┆ 32.4 ┆ 1024.4 ┆ 474.0 │
# └─────────────────────┴───────────┴─────────┴─────────┴───┴──────┴──────┴────────┴───────┘

# %%
weather_df.write_csv(RAW_DATA_DIR / "weather_daily.csv")

# %%
data_df.with_columns(pl.col("date").dt.date()).join(weather_df.with_columns(pl.col("time").dt.date().alias("date")),
                                                    on=["plz", 'date'], how="left")
# Out:
# shape: (59_790, 22)
# ┌──────────────────────┬────────────┬────────┬──────────────────┬───┬──────┬──────┬────────┬───────┐
# │ id                   ┆ date       ┆ diff   ┆ primary_energy   ┆ … ┆ wspd ┆ wpgt ┆ pres   ┆ tsun  │
# │ ---                  ┆ ---        ┆ ---    ┆ ---              ┆   ┆ ---  ┆ ---  ┆ ---    ┆ ---   │
# │ str                  ┆ date       ┆ f64    ┆ str              ┆   ┆ f64  ┆ f64  ┆ f64    ┆ f64   │
# ╞══════════════════════╪════════════╪════════╪══════════════════╪═══╪══════╪══════╪════════╪═══════╡
# │ 0c9ad311-b86f-4371-a ┆ 2022-10-01 ┆ 703.0  ┆ district heating ┆ … ┆ 18.7 ┆ 58.0 ┆ 1003.3 ┆ 156.0 │
# │ 695-512ca4…          ┆            ┆        ┆                  ┆   ┆      ┆      ┆        ┆       │
# │ 0c9ad311-b86f-4371-a ┆ 2022-10-02 ┆ 334.0  ┆ district heating ┆ … ┆ 15.1 ┆ 45.7 ┆ 1013.8 ┆ 318.0 │
# │ 695-512ca4…          ┆            ┆        ┆                  ┆   ┆      ┆      ┆        ┆       │
# │ 0c9ad311-b86f-4371-a ┆ 2022-10-03 ┆ 891.0  ┆ district heating ┆ … ┆ 13.7 ┆ 45.7 ┆ 1023.0 ┆ 138.0 │
# │ 695-512ca4…          ┆            ┆        ┆                  ┆   ┆      ┆      ┆        ┆       │
# │ 0c9ad311-b86f-4371-a ┆ 2022-10-04 ┆ 661.0  ┆ district heating ┆ … ┆ 11.5 ┆ 35.3 ┆ 1019.8 ┆ 354.0 │
# │ 695-512ca4…          ┆            ┆        ┆                  ┆   ┆      ┆      ┆        ┆       │
# │ 0c9ad311-b86f-4371-a ┆ 2022-10-05 ┆ 499.0  ┆ district heating ┆ … ┆ 22.7 ┆ 58.0 ┆ 1013.9 ┆ 0.0   │
# │ 695-512ca4…          ┆            ┆        ┆                  ┆   ┆      ┆      ┆        ┆       │
# │ …                    ┆ …          ┆ …      ┆ …                ┆ … ┆ …    ┆ …    ┆ …      ┆ …     │
# │ 4008231VG            ┆ 2022-03-11 ┆ 1435.1 ┆ gas              ┆ … ┆ 30.2 ┆ 58.0 ┆ 1023.9 ┆ 636.0 │
# │ 4008231VG            ┆ 2022-03-12 ┆ 1083.3 ┆ gas              ┆ … ┆ 23.4 ┆ 54.4 ┆ 1021.4 ┆ 594.0 │
# │ 4008231VG            ┆ 2022-03-13 ┆ 1038.4 ┆ gas              ┆ … ┆ 19.1 ┆ 38.9 ┆ 1019.6 ┆ 654.0 │
# │ 4008231VG            ┆ 2022-03-14 ┆ 996.6  ┆ gas              ┆ … ┆ 11.2 ┆ 25.9 ┆ 1023.9 ┆ 240.0 │
# │ 4008231VG            ┆ 2022-03-15 ┆ 495.5  ┆ gas              ┆ … ┆ 5.8  ┆ 18.4 ┆ 1026.9 ┆ 0.0   │
# └──────────────────────┴────────────┴────────┴──────────────────┴───┴──────┴──────┴────────┴───────┘

# %% [markdown]
# Get hourly weather data as well

# %%
from meteostat import Point, Hourly

weather_dfs = list()
for row in city_df.iter_rows():
    start = row[2]
    end = row[3]
    loc = Point(row[4], row[5])

    data = Hourly(loc, start, end)
    data = data.fetch()
    weather_dfs.append(pl.from_pandas(data.reset_index()).with_columns(pl.lit(row[1]).alias("plz")))
weather_df_hourly = pl.concat(weather_dfs)
weather_df_hourly
# Out:
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
# shape: (749_148, 13)
# ┌─────────────────────┬──────┬──────┬──────┬───┬────────┬──────┬──────┬───────┐
# │ time                ┆ temp ┆ dwpt ┆ rhum ┆ … ┆ pres   ┆ tsun ┆ coco ┆ plz   │
# │ ---                 ┆ ---  ┆ ---  ┆ ---  ┆   ┆ ---    ┆ ---  ┆ ---  ┆ ---   │
# │ datetime[ns]        ┆ f64  ┆ f64  ┆ f64  ┆   ┆ f64    ┆ f64  ┆ f64  ┆ i32   │
# ╞═════════════════════╪══════╪══════╪══════╪═══╪════════╪══════╪══════╪═══════╡
# │ 2022-10-01 00:00:00 ┆ 10.1 ┆ 6.2  ┆ 77.0 ┆ … ┆ 1006.2 ┆ 0.0  ┆ 4.0  ┆ 22850 │
# │ 2022-10-01 01:00:00 ┆ 10.5 ┆ 6.3  ┆ 75.0 ┆ … ┆ 1005.5 ┆ 0.0  ┆ 4.0  ┆ 22850 │
# │ 2022-10-01 02:00:00 ┆ 11.0 ┆ 6.3  ┆ 73.0 ┆ … ┆ 1004.7 ┆ 0.0  ┆ 4.0  ┆ 22850 │
# │ 2022-10-01 03:00:00 ┆ 10.8 ┆ 6.4  ┆ 74.0 ┆ … ┆ 1003.6 ┆ 0.0  ┆ 4.0  ┆ 22850 │
# │ 2022-10-01 04:00:00 ┆ 10.9 ┆ 6.4  ┆ 74.0 ┆ … ┆ 1003.1 ┆ 0.0  ┆ 8.0  ┆ 22850 │
# │ …                   ┆ …    ┆ …    ┆ …    ┆ … ┆ …      ┆ …    ┆ …    ┆ …     │
# │ 2023-09-24 20:00:00 ┆ 11.2 ┆ 10.4 ┆ 95.0 ┆ … ┆ 1026.8 ┆ 0.0  ┆ 1.0  ┆ 21077 │
# │ 2023-09-24 21:00:00 ┆ 10.3 ┆ 9.8  ┆ 97.0 ┆ … ┆ 1026.5 ┆ 0.0  ┆ 1.0  ┆ 21077 │
# │ 2023-09-24 22:00:00 ┆ 10.0 ┆ 9.5  ┆ 97.0 ┆ … ┆ 1026.2 ┆ 0.0  ┆ 1.0  ┆ 21077 │
# │ 2023-09-24 23:00:00 ┆ 12.4 ┆ 9.9  ┆ 85.0 ┆ … ┆ 1025.8 ┆ 0.0  ┆ 1.0  ┆ 21077 │
# │ 2023-09-25 00:00:00 ┆ 11.9 ┆ 9.3  ┆ 84.0 ┆ … ┆ 1025.0 ┆ 0.0  ┆ 1.0  ┆ 21077 │
# └─────────────────────┴──────┴──────┴──────┴───┴────────┴──────┴──────┴───────┘

# %%
weather_df_hourly.write_csv(RAW_DATA_DIR / "weather_hourly.csv")

# %% [markdown]
# ## Time Features
#
# School/University Break, Holidays

# %%
import holidays

holiday_dict = dict()
ger_holidays = holidays.country_holidays("DE", years=range(2018, 2024))
holiday_dict.update(ger_holidays)
holiday_dict
# Out:
# {datetime.date(2018, 1, 1): "New Year's Day",
#  datetime.date(2018, 3, 30): 'Good Friday',
#  datetime.date(2018, 4, 2): 'Easter Monday',
#  datetime.date(2018, 5, 1): 'Labor Day',
#  datetime.date(2018, 5, 10): 'Ascension Day',
#  datetime.date(2018, 5, 21): 'Whit Monday',
#  datetime.date(2018, 10, 3): 'German Unity Day',
#  datetime.date(2018, 12, 25): 'Christmas Day',
#  datetime.date(2018, 12, 26): 'Second Day of Christmas',
#  datetime.date(2019, 1, 1): "New Year's Day",
#  datetime.date(2019, 4, 19): 'Good Friday',
#  datetime.date(2019, 4, 22): 'Easter Monday',
#  datetime.date(2019, 5, 1): 'Labor Day',
#  datetime.date(2019, 5, 30): 'Ascension Day',
#  datetime.date(2019, 6, 10): 'Whit Monday',
#  datetime.date(2019, 10, 3): 'German Unity Day',
#  datetime.date(2019, 12, 25): 'Christmas Day',
#  datetime.date(2019, 12, 26): 'Second Day of Christmas',
#  datetime.date(2020, 1, 1): "New Year's Day",
#  datetime.date(2020, 4, 10): 'Good Friday',
#  datetime.date(2020, 4, 13): 'Easter Monday',
#  datetime.date(2020, 5, 1): 'Labor Day',
#  datetime.date(2020, 5, 21): 'Ascension Day',
#  datetime.date(2020, 6, 1): 'Whit Monday',
#  datetime.date(2020, 10, 3): 'German Unity Day',
#  datetime.date(2020, 12, 25): 'Christmas Day',
#  datetime.date(2020, 12, 26): 'Second Day of Christmas',
#  datetime.date(2021, 1, 1): "New Year's Day",
#  datetime.date(2021, 4, 2): 'Good Friday',
#  datetime.date(2021, 4, 5): 'Easter Monday',
#  datetime.date(2021, 5, 1): 'Labor Day',
#  datetime.date(2021, 5, 13): 'Ascension Day',
#  datetime.date(2021, 5, 24): 'Whit Monday',
#  datetime.date(2021, 10, 3): 'German Unity Day',
#  datetime.date(2021, 12, 25): 'Christmas Day',
#  datetime.date(2021, 12, 26): 'Second Day of Christmas',
#  datetime.date(2022, 1, 1): "New Year's Day",
#  datetime.date(2022, 4, 15): 'Good Friday',
#  datetime.date(2022, 4, 18): 'Easter Monday',
#  datetime.date(2022, 5, 1): 'Labor Day',
#  datetime.date(2022, 5, 26): 'Ascension Day',
#  datetime.date(2022, 6, 6): 'Whit Monday',
#  datetime.date(2022, 10, 3): 'German Unity Day',
#  datetime.date(2022, 12, 25): 'Christmas Day',
#  datetime.date(2022, 12, 26): 'Second Day of Christmas',
#  datetime.date(2023, 1, 1): "New Year's Day",
#  datetime.date(2023, 4, 7): 'Good Friday',
#  datetime.date(2023, 4, 10): 'Easter Monday',
#  datetime.date(2023, 5, 1): 'Labor Day',
#  datetime.date(2023, 5, 18): 'Ascension Day',
#  datetime.date(2023, 5, 29): 'Whit Monday',
#  datetime.date(2023, 10, 3): 'German Unity Day',
#  datetime.date(2023, 12, 25): 'Christmas Day',
#  datetime.date(2023, 12, 26): 'Second Day of Christmas'}

# %%
for state in city_df["state"].unique():
    state_holidays = holidays.country_holidays("DE", subdiv=state, years=range(2018, 2024))
    holiday_dict.update(state_holidays)
holiday_dict
# Out:
# {datetime.date(2018, 1, 1): "New Year's Day",
#  datetime.date(2018, 3, 30): 'Good Friday',
#  datetime.date(2018, 4, 2): 'Easter Monday',
#  datetime.date(2018, 5, 1): 'Labor Day',
#  datetime.date(2018, 5, 10): 'Ascension Day',
#  datetime.date(2018, 5, 21): 'Whit Monday',
#  datetime.date(2018, 10, 3): 'German Unity Day',
#  datetime.date(2018, 12, 25): 'Christmas Day',
#  datetime.date(2018, 12, 26): 'Second Day of Christmas',
#  datetime.date(2019, 1, 1): "New Year's Day",
#  datetime.date(2019, 4, 19): 'Good Friday',
#  datetime.date(2019, 4, 22): 'Easter Monday',
#  datetime.date(2019, 5, 1): 'Labor Day',
#  datetime.date(2019, 5, 30): 'Ascension Day',
#  datetime.date(2019, 6, 10): 'Whit Monday',
#  datetime.date(2019, 10, 3): 'German Unity Day',
#  datetime.date(2019, 12, 25): 'Christmas Day',
#  datetime.date(2019, 12, 26): 'Second Day of Christmas',
#  datetime.date(2020, 1, 1): "New Year's Day",
#  datetime.date(2020, 4, 10): 'Good Friday',
#  datetime.date(2020, 4, 13): 'Easter Monday',
#  datetime.date(2020, 5, 1): 'Labor Day',
#  datetime.date(2020, 5, 21): 'Ascension Day',
#  datetime.date(2020, 6, 1): 'Whit Monday',
#  datetime.date(2020, 10, 3): 'German Unity Day',
#  datetime.date(2020, 12, 25): 'Christmas Day',
#  datetime.date(2020, 12, 26): 'Second Day of Christmas',
#  datetime.date(2021, 1, 1): "New Year's Day",
#  datetime.date(2021, 4, 2): 'Good Friday',
#  datetime.date(2021, 4, 5): 'Easter Monday',
#  datetime.date(2021, 5, 1): 'Labor Day',
#  datetime.date(2021, 5, 13): 'Ascension Day',
#  datetime.date(2021, 5, 24): 'Whit Monday',
#  datetime.date(2021, 10, 3): 'German Unity Day',
#  datetime.date(2021, 12, 25): 'Christmas Day',
#  datetime.date(2021, 12, 26): 'Second Day of Christmas',
#  datetime.date(2022, 1, 1): "New Year's Day",
#  datetime.date(2022, 4, 15): 'Good Friday',
#  datetime.date(2022, 4, 18): 'Easter Monday',
#  datetime.date(2022, 5, 1): 'Labor Day',
#  datetime.date(2022, 5, 26): 'Ascension Day',
#  datetime.date(2022, 6, 6): 'Whit Monday',
#  datetime.date(2022, 10, 3): 'German Unity Day',
#  datetime.date(2022, 12, 25): 'Christmas Day',
#  datetime.date(2022, 12, 26): 'Second Day of Christmas',
#  datetime.date(2023, 1, 1): "New Year's Day",
#  datetime.date(2023, 4, 7): 'Good Friday',
#  datetime.date(2023, 4, 10): 'Easter Monday',
#  datetime.date(2023, 5, 1): 'Labor Day',
#  datetime.date(2023, 5, 18): 'Ascension Day',
#  datetime.date(2023, 5, 29): 'Whit Monday',
#  datetime.date(2023, 10, 3): 'German Unity Day',
#  datetime.date(2023, 12, 25): 'Christmas Day',
#  datetime.date(2023, 12, 26): 'Second Day of Christmas',
#  datetime.date(2018, 10, 31): 'Reformation Day',
#  datetime.date(2019, 10, 31): 'Reformation Day',
#  datetime.date(2020, 10, 31): 'Reformation Day',
#  datetime.date(2021, 10, 31): 'Reformation Day',
#  datetime.date(2022, 10, 31): 'Reformation Day',
#  datetime.date(2023, 10, 31): 'Reformation Day',
#  datetime.date(2019, 3, 8): "International Women's Day",
#  datetime.date(2020, 3, 8): "International Women's Day",
#  datetime.date(2020, 5, 8): '75th anniversary of the liberation from Nazism and the end of the Second World War in Europe',
#  datetime.date(2021, 3, 8): "International Women's Day",
#  datetime.date(2022, 3, 8): "International Women's Day",
#  datetime.date(2023, 3, 8): "International Women's Day",
#  datetime.date(2018, 1, 6): 'Epiphany',
#  datetime.date(2018, 5, 31): 'Corpus Christi',
#  datetime.date(2018, 8, 15): 'Assumption Day',
#  datetime.date(2018, 11, 1): "All Saints' Day",
#  datetime.date(2019, 1, 6): 'Epiphany',
#  datetime.date(2019, 6, 20): 'Corpus Christi',
#  datetime.date(2019, 8, 15): 'Assumption Day',
#  datetime.date(2019, 11, 1): "All Saints' Day",
#  datetime.date(2020, 1, 6): 'Epiphany',
#  datetime.date(2020, 6, 11): 'Corpus Christi',
#  datetime.date(2020, 8, 15): 'Assumption Day',
#  datetime.date(2020, 11, 1): "All Saints' Day",
#  datetime.date(2021, 1, 6): 'Epiphany',
#  datetime.date(2021, 6, 3): 'Corpus Christi',
#  datetime.date(2021, 8, 15): 'Assumption Day',
#  datetime.date(2021, 11, 1): "All Saints' Day",
#  datetime.date(2022, 1, 6): 'Epiphany',
#  datetime.date(2022, 6, 16): 'Corpus Christi',
#  datetime.date(2022, 8, 15): 'Assumption Day',
#  datetime.date(2022, 11, 1): "All Saints' Day",
#  datetime.date(2023, 1, 6): 'Epiphany',
#  datetime.date(2023, 6, 8): 'Corpus Christi',
#  datetime.date(2023, 8, 15): 'Assumption Day',
#  datetime.date(2023, 11, 1): "All Saints' Day"}

# %%
data_df.with_columns(pl.col("date").dt.date().alias("date"))
# Out:
# shape: (59_790, 8)
# ┌───────────────┬────────────┬────────┬──────────────┬──────────────┬─────────────┬───────┬────────┐
# │ id            ┆ date       ┆ diff   ┆ primary_ener ┆ adresse      ┆ ort         ┆ plz   ┆ source │
# │ ---           ┆ ---        ┆ ---    ┆ gy           ┆ ---          ┆ ---         ┆ ---   ┆ ---    │
# │ str           ┆ date       ┆ f64    ┆ ---          ┆ str          ┆ str         ┆ i64   ┆ str    │
# │               ┆            ┆        ┆ str          ┆              ┆             ┆       ┆        │
# ╞═══════════════╪════════════╪════════╪══════════════╪══════════════╪═════════════╪═══════╪════════╡
# │ 0c9ad311-b86f ┆ 2022-10-01 ┆ 703.0  ┆ district     ┆ Kielortring  ┆ Norderstedt ┆ 22850 ┆ dh     │
# │ -4371-a695-51 ┆            ┆        ┆ heating      ┆ 14           ┆             ┆       ┆        │
# │ 2ca4…         ┆            ┆        ┆              ┆              ┆             ┆       ┆        │
# │ 0c9ad311-b86f ┆ 2022-10-02 ┆ 334.0  ┆ district     ┆ Kielortring  ┆ Norderstedt ┆ 22850 ┆ dh     │
# │ -4371-a695-51 ┆            ┆        ┆ heating      ┆ 14           ┆             ┆       ┆        │
# │ 2ca4…         ┆            ┆        ┆              ┆              ┆             ┆       ┆        │
# │ 0c9ad311-b86f ┆ 2022-10-03 ┆ 891.0  ┆ district     ┆ Kielortring  ┆ Norderstedt ┆ 22850 ┆ dh     │
# │ -4371-a695-51 ┆            ┆        ┆ heating      ┆ 14           ┆             ┆       ┆        │
# │ 2ca4…         ┆            ┆        ┆              ┆              ┆             ┆       ┆        │
# │ 0c9ad311-b86f ┆ 2022-10-04 ┆ 661.0  ┆ district     ┆ Kielortring  ┆ Norderstedt ┆ 22850 ┆ dh     │
# │ -4371-a695-51 ┆            ┆        ┆ heating      ┆ 14           ┆             ┆       ┆        │
# │ 2ca4…         ┆            ┆        ┆              ┆              ┆             ┆       ┆        │
# │ 0c9ad311-b86f ┆ 2022-10-05 ┆ 499.0  ┆ district     ┆ Kielortring  ┆ Norderstedt ┆ 22850 ┆ dh     │
# │ -4371-a695-51 ┆            ┆        ┆ heating      ┆ 14           ┆             ┆       ┆        │
# │ 2ca4…         ┆            ┆        ┆              ┆              ┆             ┆       ┆        │
# │ …             ┆ …          ┆ …      ┆ …            ┆ …            ┆ …           ┆ …     ┆ …      │
# │ 4008231VG     ┆ 2022-03-11 ┆ 1435.1 ┆ gas          ┆ Tinnumer Weg ┆ Hamburg     ┆ 22117 ┆ legacy │
# │               ┆            ┆        ┆              ┆ 1-9,         ┆             ┆       ┆        │
# │               ┆            ┆        ┆              ┆ Morsumer     ┆             ┆       ┆        │
# │               ┆            ┆        ┆              ┆ Weg…         ┆             ┆       ┆        │
# │ 4008231VG     ┆ 2022-03-12 ┆ 1083.3 ┆ gas          ┆ Tinnumer Weg ┆ Hamburg     ┆ 22117 ┆ legacy │
# │               ┆            ┆        ┆              ┆ 1-9,         ┆             ┆       ┆        │
# │               ┆            ┆        ┆              ┆ Morsumer     ┆             ┆       ┆        │
# │               ┆            ┆        ┆              ┆ Weg…         ┆             ┆       ┆        │
# │ 4008231VG     ┆ 2022-03-13 ┆ 1038.4 ┆ gas          ┆ Tinnumer Weg ┆ Hamburg     ┆ 22117 ┆ legacy │
# │               ┆            ┆        ┆              ┆ 1-9,         ┆             ┆       ┆        │
# │               ┆            ┆        ┆              ┆ Morsumer     ┆             ┆       ┆        │
# │               ┆            ┆        ┆              ┆ Weg…         ┆             ┆       ┆        │
# │ 4008231VG     ┆ 2022-03-14 ┆ 996.6  ┆ gas          ┆ Tinnumer Weg ┆ Hamburg     ┆ 22117 ┆ legacy │
# │               ┆            ┆        ┆              ┆ 1-9,         ┆             ┆       ┆        │
# │               ┆            ┆        ┆              ┆ Morsumer     ┆             ┆       ┆        │
# │               ┆            ┆        ┆              ┆ Weg…         ┆             ┆       ┆        │
# │ 4008231VG     ┆ 2022-03-15 ┆ 495.5  ┆ gas          ┆ Tinnumer Weg ┆ Hamburg     ┆ 22117 ┆ legacy │
# │               ┆            ┆        ┆              ┆ 1-9,         ┆             ┆       ┆        │
# │               ┆            ┆        ┆              ┆ Morsumer     ┆             ┆       ┆        │
# │               ┆            ┆        ┆              ┆ Weg…         ┆             ┆       ┆        │
# └───────────────┴────────────┴────────┴──────────────┴──────────────┴─────────────┴───────┴────────┘

# %%
data_df = data_df.with_columns(pl.col("date").dt.date().alias("date")
                               ).with_columns(
    pl.when(pl.col("date").is_in(set(holiday_dict.keys()))).then(1).otherwise(0).alias("holiday"))
data_df
# Out:
# shape: (59_790, 9)
# ┌───────────────┬────────────┬────────┬───────────────┬───┬─────────────┬───────┬────────┬─────────┐
# │ id            ┆ date       ┆ diff   ┆ primary_energ ┆ … ┆ ort         ┆ plz   ┆ source ┆ holiday │
# │ ---           ┆ ---        ┆ ---    ┆ y             ┆   ┆ ---         ┆ ---   ┆ ---    ┆ ---     │
# │ str           ┆ date       ┆ f64    ┆ ---           ┆   ┆ str         ┆ i64   ┆ str    ┆ i32     │
# │               ┆            ┆        ┆ str           ┆   ┆             ┆       ┆        ┆         │
# ╞═══════════════╪════════════╪════════╪═══════════════╪═══╪═════════════╪═══════╪════════╪═════════╡
# │ 0c9ad311-b86f ┆ 2022-10-01 ┆ 703.0  ┆ district      ┆ … ┆ Norderstedt ┆ 22850 ┆ dh     ┆ 0       │
# │ -4371-a695-51 ┆            ┆        ┆ heating       ┆   ┆             ┆       ┆        ┆         │
# │ 2ca4…         ┆            ┆        ┆               ┆   ┆             ┆       ┆        ┆         │
# │ 0c9ad311-b86f ┆ 2022-10-02 ┆ 334.0  ┆ district      ┆ … ┆ Norderstedt ┆ 22850 ┆ dh     ┆ 0       │
# │ -4371-a695-51 ┆            ┆        ┆ heating       ┆   ┆             ┆       ┆        ┆         │
# │ 2ca4…         ┆            ┆        ┆               ┆   ┆             ┆       ┆        ┆         │
# │ 0c9ad311-b86f ┆ 2022-10-03 ┆ 891.0  ┆ district      ┆ … ┆ Norderstedt ┆ 22850 ┆ dh     ┆ 1       │
# │ -4371-a695-51 ┆            ┆        ┆ heating       ┆   ┆             ┆       ┆        ┆         │
# │ 2ca4…         ┆            ┆        ┆               ┆   ┆             ┆       ┆        ┆         │
# │ 0c9ad311-b86f ┆ 2022-10-04 ┆ 661.0  ┆ district      ┆ … ┆ Norderstedt ┆ 22850 ┆ dh     ┆ 0       │
# │ -4371-a695-51 ┆            ┆        ┆ heating       ┆   ┆             ┆       ┆        ┆         │
# │ 2ca4…         ┆            ┆        ┆               ┆   ┆             ┆       ┆        ┆         │
# │ 0c9ad311-b86f ┆ 2022-10-05 ┆ 499.0  ┆ district      ┆ … ┆ Norderstedt ┆ 22850 ┆ dh     ┆ 0       │
# │ -4371-a695-51 ┆            ┆        ┆ heating       ┆   ┆             ┆       ┆        ┆         │
# │ 2ca4…         ┆            ┆        ┆               ┆   ┆             ┆       ┆        ┆         │
# │ …             ┆ …          ┆ …      ┆ …             ┆ … ┆ …           ┆ …     ┆ …      ┆ …       │
# │ 4008231VG     ┆ 2022-03-11 ┆ 1435.1 ┆ gas           ┆ … ┆ Hamburg     ┆ 22117 ┆ legacy ┆ 0       │
# │ 4008231VG     ┆ 2022-03-12 ┆ 1083.3 ┆ gas           ┆ … ┆ Hamburg     ┆ 22117 ┆ legacy ┆ 0       │
# │ 4008231VG     ┆ 2022-03-13 ┆ 1038.4 ┆ gas           ┆ … ┆ Hamburg     ┆ 22117 ┆ legacy ┆ 0       │
# │ 4008231VG     ┆ 2022-03-14 ┆ 996.6  ┆ gas           ┆ … ┆ Hamburg     ┆ 22117 ┆ legacy ┆ 0       │
# │ 4008231VG     ┆ 2022-03-15 ┆ 495.5  ┆ gas           ┆ … ┆ Hamburg     ┆ 22117 ┆ legacy ┆ 0       │
# └───────────────┴────────────┴────────┴───────────────┴───┴─────────────┴───────┴────────┴─────────┘

# %% [markdown]
# ## Building Features

# %% [markdown]
# ### Legacy Data

# %%
leg_data = pl.read_csv(RAW_DATA_DIR / "legacy_daily.csv")
leg_data_meta = leg_data.group_by(
    ["id", "ort", "adresse", "plz", "primary_energy", "qmbehfl", "anzlwhg", "co2koeffizient"]).agg().with_columns(pl.lit("Mehrfamilienhaus").alias("typ")).rename({"anzlwhg": "anzahlwhg"})
leg_data_meta = leg_data_meta.rename({"qmbehfl": "heated_area"}).cast(
    {"heated_area": pl.Float64, "plz": pl.String}).with_columns(pl.lit("leg").alias("source"))
leg_data_meta
# Out:
# shape: (29, 10)
# ┌───────────┬─────────────┬─────────────┬───────┬───┬───────────┬────────────┬────────────┬────────┐
# │ id        ┆ ort         ┆ adresse     ┆ plz   ┆ … ┆ anzahlwhg ┆ co2koeffiz ┆ typ        ┆ source │
# │ ---       ┆ ---         ┆ ---         ┆ ---   ┆   ┆ ---       ┆ ient       ┆ ---        ┆ ---    │
# │ str       ┆ str         ┆ str         ┆ str   ┆   ┆ i64       ┆ ---        ┆ str        ┆ str    │
# │           ┆             ┆             ┆       ┆   ┆           ┆ f64        ┆            ┆        │
# ╞═══════════╪═════════════╪═════════════╪═══════╪═══╪═══════════╪════════════╪════════════╪════════╡
# │ 400308PVG ┆ Hamburg     ┆ Martinistra ┆ 20251 ┆ … ┆ 0         ┆ 2.26       ┆ Mehrfamili ┆ leg    │
# │           ┆             ┆ ße 44       ┆       ┆   ┆           ┆            ┆ enhaus     ┆        │
# │ 400690GVG ┆ Hamburg     ┆ Op´n        ┆ 22589 ┆ … ┆ 290       ┆ 2.26       ┆ Mehrfamili ┆ leg    │
# │           ┆             ┆ Hainholt    ┆       ┆   ┆           ┆            ┆ enhaus     ┆        │
# │           ┆             ┆ 4-18        ┆       ┆   ┆           ┆            ┆            ┆        │
# │ 400356PVG ┆ Elmshorn    ┆ Fehrsstraße ┆ 25336 ┆ … ┆ 23        ┆ 2.26       ┆ Mehrfamili ┆ leg    │
# │           ┆             ┆ 7           ┆       ┆   ┆           ┆            ┆ enhaus     ┆        │
# │ 400131GVG ┆ Lübeck      ┆ Brandenbaum ┆ 23566 ┆ … ┆ 120       ┆ 2.26       ┆ Mehrfamili ┆ leg    │
# │           ┆             ┆ er          ┆       ┆   ┆           ┆            ┆ enhaus     ┆        │
# │           ┆             ┆ Landstraße  ┆       ┆   ┆           ┆            ┆            ┆        │
# │           ┆             ┆ 177         ┆       ┆   ┆           ┆            ┆            ┆        │
# │ 4008231VG ┆ Hamburg     ┆ Tinnumer    ┆ 22117 ┆ … ┆ 262       ┆ 2.26       ┆ Mehrfamili ┆ leg    │
# │           ┆             ┆ Weg 1-9,    ┆       ┆   ┆           ┆            ┆ enhaus     ┆        │
# │           ┆             ┆ Morsumer    ┆       ┆   ┆           ┆            ┆            ┆        │
# │           ┆             ┆ Weg…        ┆       ┆   ┆           ┆            ┆            ┆        │
# │ …         ┆ …           ┆ …           ┆ …     ┆ … ┆ …         ┆ …          ┆ …          ┆ …      │
# │ 400768GVG ┆ Hamburg     ┆ Schenfelder ┆ 22589 ┆ … ┆ 697       ┆ 2.26       ┆ Mehrfamili ┆ leg    │
# │           ┆             ┆ Holt 135    ┆       ┆   ┆           ┆            ┆ enhaus     ┆        │
# │ 400287SVG ┆ Schwarzenbe ┆ Verbrüderun ┆ 21493 ┆ … ┆ 51        ┆ 2.26       ┆ Mehrfamili ┆ leg    │
# │           ┆ k           ┆ gsring 21   ┆       ┆   ┆           ┆            ┆ enhaus     ┆        │
# │ 400711GVG ┆ Hamburg     ┆ Dahlgrünrin ┆ 21109 ┆ … ┆ 96        ┆ 2.26       ┆ Mehrfamili ┆ leg    │
# │           ┆             ┆ g 5-9       ┆       ┆   ┆           ┆            ┆ enhaus     ┆        │
# │ 400067GVG ┆ Elmshorn    ┆ Friedensall ┆ 25335 ┆ … ┆ 94        ┆ 2.26       ┆ Mehrfamili ┆ leg    │
# │           ┆             ┆ ee 13       ┆       ┆   ┆           ┆            ┆ enhaus     ┆        │
# │ 4007060VG ┆ Hamburg     ┆ Süderelberi ┆ 21149 ┆ … ┆ 0         ┆ 2.26       ┆ Mehrfamili ┆ leg    │
# │           ┆             ┆ ng 2        ┆       ┆   ┆           ┆            ┆ enhaus     ┆        │
# └───────────┴─────────────┴─────────────┴───────┴───┴───────────┴────────────┴────────────┴────────┘

# %%
leg_data_meta.write_csv(RAW_DATA_DIR / "legacy_meta.csv")

# %% [markdown]
# ### Kinergy Data

# %%
from src.energy_forecast.config import DATA_DIR
import json

with open(DATA_DIR / "kinergy" / "kinergy_eco_u_list.json", "r", encoding="UTF-8") as f:
    eco_u_data = json.loads(f.read())
item_list = [i for k, i in eco_u_data.items()]
kinergy_meta = pl.from_dicts(item_list).select(
    ["hash", "ort", "name", "plz", "anzahlwhg", "typ", "complexity", "complexity_score", "primary_energy",
     "heated_area", "renewable_energy_used", "has_pwh", "pwh_type", "netz_nummer"])

bem_meta = pl.read_csv(DATA_DIR / "kinergy" / "berlin_fernwärmenetz_info.csv").rename(
    {"Netznummer": "netz_nummer"}).select(["netz_nummer", "min_vorlauf_temp", "max_vorlauf_temp"])
kinergy_meta = kinergy_meta.join(bem_meta, on="netz_nummer", how="left")
kinergy_meta = kinergy_meta.rename({"hash": "id", "name": "adresse"}).with_columns(pl.lit("kin").alias("source"))
kinergy_meta
# Out:
# shape: (20, 16)
# ┌────────────┬──────────┬────────────┬───────┬───┬───────────┬────────────┬────────────┬───────────┐
# │ hash       ┆ ort      ┆ name       ┆ plz   ┆ … ┆ pwh_type  ┆ netz_numme ┆ min_vorlau ┆ max_vorla │
# │ ---        ┆ ---      ┆ ---        ┆ ---   ┆   ┆ ---       ┆ r          ┆ f_temp     ┆ uf_temp   │
# │ str        ┆ str      ┆ str        ┆ str   ┆   ┆ str       ┆ ---        ┆ ---        ┆ ---       │
# │            ┆          ┆            ┆       ┆   ┆           ┆ i64        ┆ str        ┆ str       │
# ╞════════════╪══════════╪════════════╪═══════╪═══╪═══════════╪════════════╪════════════╪═══════════╡
# │ 1 # JHe51  ┆ Bamberg  ┆ Hegelstraß ┆ 96052 ┆ … ┆ central   ┆ null       ┆ null       ┆ null      │
# │            ┆          ┆ e 51       ┆       ┆   ┆           ┆            ┆            ┆           │
# │ 2 # JMe4   ┆ Erlangen ┆ Mittlere   ┆ 91054 ┆ … ┆ central   ┆ null       ┆ null       ┆ null      │
# │            ┆          ┆ Schulstraß ┆       ┆   ┆           ┆            ┆            ┆           │
# │            ┆          ┆ e 4        ┆       ┆   ┆           ┆            ┆            ┆           │
# │ 3 # JOe11  ┆ Erlangen ┆ Otto-Goetz ┆ 91054 ┆ … ┆ central   ┆ null       ┆ null       ┆ null      │
# │            ┆          ┆ e-Straße   ┆       ┆   ┆           ┆            ┆            ┆           │
# │            ┆          ┆ 11         ┆       ┆   ┆           ┆            ┆            ┆           │
# │ 4 #        ┆ Bayreuth ┆ Schellings ┆ 95447 ┆ … ┆ central   ┆ null       ┆ null       ┆ null      │
# │ JSe21/23   ┆          ┆ traße      ┆       ┆   ┆           ┆            ┆            ┆           │
# │            ┆          ┆ 21/23      ┆       ┆   ┆           ┆            ┆            ┆           │
# │ 5 #        ┆ Würzburg ┆ Friedrichs ┆ 97082 ┆ … ┆ decentral ┆ null       ┆ null       ┆ null      │
# │ WFe21-25   ┆          ┆ traße      ┆       ┆   ┆           ┆            ┆            ┆           │
# │            ┆          ┆ 21-25      ┆       ┆   ┆           ┆            ┆            ┆           │
# │ …          ┆ …        ┆ …          ┆ …     ┆ … ┆ …         ┆ …          ┆ …          ┆ …         │
# │ 16 # PRe45 ┆ Plön     ┆ Rautenberg ┆ 24306 ┆ … ┆ central   ┆ null       ┆ null       ┆ null      │
# │            ┆          ┆ straße 45  ┆       ┆   ┆           ┆            ┆            ┆           │
# │ 17 # SFp36 ┆ Hamburg  ┆ Foorthkamp ┆ 22419 ┆ … ┆ central   ┆ null       ┆ null       ┆ null      │
# │            ┆          ┆ 36         ┆       ┆   ┆           ┆            ┆            ┆           │
# │ 18 #       ┆ Hamburg  ┆ Gaußstraße ┆ 22765 ┆ … ┆ null      ┆ null       ┆ null       ┆ null      │
# │ SGe171     ┆          ┆ 171        ┆       ┆   ┆           ┆            ┆            ┆           │
# │ 19 # SKg63 ┆ Hamburg  ┆ Kapellenwe ┆ 21077 ┆ … ┆ central   ┆ null       ┆ null       ┆ null      │
# │            ┆          ┆ g 63       ┆       ┆   ┆           ┆            ┆            ┆           │
# │ 20 #       ┆ Hamburg  ┆ Slomanstie ┆ 20539 ┆ … ┆ central   ┆ null       ┆ null       ┆ null      │
# │ SSg1-3     ┆          ┆ g 1-3      ┆       ┆   ┆           ┆            ┆            ┆           │
# └────────────┴──────────┴────────────┴───────┴───┴───────────┴────────────┴────────────┴───────────┘

# %%
kinergy_meta.filter(pl.col("primary_energy") == "district heating")
# Out:
# shape: (6, 16)
# ┌────────────┬──────────┬────────────┬───────┬───┬───────────┬────────────┬────────────┬───────────┐
# │ hash       ┆ ort      ┆ name       ┆ plz   ┆ … ┆ pwh_type  ┆ netz_numme ┆ min_vorlau ┆ max_vorla │
# │ ---        ┆ ---      ┆ ---        ┆ ---   ┆   ┆ ---       ┆ r          ┆ f_temp     ┆ uf_temp   │
# │ str        ┆ str      ┆ str        ┆ str   ┆   ┆ str       ┆ ---        ┆ ---        ┆ ---       │
# │            ┆          ┆            ┆       ┆   ┆           ┆ i64        ┆ str        ┆ str       │
# ╞════════════╪══════════╪════════════╪═══════╪═══╪═══════════╪════════════╪════════════╪═══════════╡
# │ 1 # JHe51  ┆ Bamberg  ┆ Hegelstraß ┆ 96052 ┆ … ┆ central   ┆ null       ┆ null       ┆ null      │
# │            ┆          ┆ e 51       ┆       ┆   ┆           ┆            ┆            ┆           │
# │ 5 #        ┆ Würzburg ┆ Friedrichs ┆ 97082 ┆ … ┆ decentral ┆ null       ┆ null       ┆ null      │
# │ WFe21-25   ┆          ┆ traße      ┆       ┆   ┆           ┆            ┆            ┆           │
# │            ┆          ┆ 21-25      ┆       ┆   ┆           ┆            ┆            ┆           │
# │ 9 # BMr03  ┆ Berlin   ┆ Marzahner  ┆ 12681 ┆ … ┆ central   ┆ 2100       ┆  80 °C     ┆  135 °C   │
# │            ┆          ┆ Chaussee   ┆       ┆   ┆           ┆            ┆            ┆           │
# │            ┆          ┆ 231        ┆       ┆   ┆           ┆            ┆            ┆           │
# │            ┆          ┆ Sportha…   ┆       ┆   ┆           ┆            ┆            ┆           │
# │ 10 #       ┆ Berlin   ┆ Straßmanns ┆ 10249 ┆ … ┆ null      ┆ 2600       ┆  80 °C     ┆  135 °C   │
# │ BSeH1+3+4  ┆          ┆ traße      ┆       ┆   ┆           ┆            ┆            ┆           │
# │            ┆          ┆ 14-16      ┆       ┆   ┆           ┆            ┆            ┆           │
# │            ┆          ┆ H1+3+4     ┆       ┆   ┆           ┆            ┆            ┆           │
# │ 11 # BSeH2 ┆ Berlin   ┆ Straßmanns ┆ 10249 ┆ … ┆ central   ┆ 2600       ┆  80 °C     ┆  135 °C   │
# │            ┆          ┆ traße      ┆       ┆   ┆           ┆            ┆            ┆           │
# │            ┆          ┆ 14-16 H2   ┆       ┆   ┆           ┆            ┆            ┆           │
# │ 12 # BTr9  ┆ Berlin   ┆ Trebbiner  ┆ 10963 ┆ … ┆ null      ┆ 2601       ┆  80 °C     ┆  135 °C   │
# │            ┆          ┆ Str.9      ┆       ┆   ┆           ┆            ┆            ┆           │
# └────────────┴──────────┴────────────┴───────┴───┴───────────┴────────────┴────────────┴───────────┘

# %% [markdown]
# ### District Heating Data

# %%
dh_meta = pl.read_csv(RAW_DATA_DIR / "district_heating_meta.csv").with_columns(
    pl.lit("Mehrfamilienhaus").alias("typ"),
    pl.lit(75).alias("min_vorlauf_temp"),
    pl.lit(90).alias("max_vorlauf_temp")
).rename({"eco_u_id": "id"}).select(
    ["id", "city", "address", "postal_code", "typ", "min_vorlauf_temp", "max_vorlauf_temp"])
dh_meta = dh_meta.rename({"address": "adresse", "postal_code": "plz", "city": "ort"}).select(
    ["id", "adresse", "ort", "plz", "typ", "min_vorlauf_temp", "max_vorlauf_temp"]).cast(
    {"plz": pl.String, "min_vorlauf_temp": pl.String, "max_vorlauf_temp": pl.String}).with_columns(
    pl.lit("dh").alias("source"),
    pl.lit("district heating").alias("primary_energy")
)
dh_meta
# Out:
# shape: (90, 9)
# ┌────────────┬────────────┬────────────┬───────┬───┬────────────┬────────────┬────────┬────────────┐
# │ id         ┆ adresse    ┆ ort        ┆ plz   ┆ … ┆ min_vorlau ┆ max_vorlau ┆ source ┆ primary_en │
# │ ---        ┆ ---        ┆ ---        ┆ ---   ┆   ┆ f_temp     ┆ f_temp     ┆ ---    ┆ ergy       │
# │ str        ┆ str        ┆ str        ┆ str   ┆   ┆ ---        ┆ ---        ┆ str    ┆ ---        │
# │            ┆            ┆            ┆       ┆   ┆ str        ┆ str        ┆        ┆ str        │
# ╞════════════╪════════════╪════════════╪═══════╪═══╪════════════╪════════════╪════════╪════════════╡
# │ 8f7b3862-a ┆ Kielort 20 ┆ Nordersted ┆ 22850 ┆ … ┆ 75         ┆ 90         ┆ dh     ┆ district   │
# │ 50d-44eb-8 ┆            ┆ t          ┆       ┆   ┆            ┆            ┆        ┆ heating    │
# │ ac9-de0cf4 ┆            ┆            ┆       ┆   ┆            ┆            ┆        ┆            │
# │ …          ┆            ┆            ┆       ┆   ┆            ┆            ┆        ┆            │
# │ 42d6efdc-d ┆ Moorbekstr ┆ Nordersted ┆ 22846 ┆ … ┆ 75         ┆ 90         ┆ dh     ┆ district   │
# │ 590-40b7-a ┆ aße 19     ┆ t          ┆       ┆   ┆            ┆            ┆        ┆ heating    │
# │ f9a-90121d ┆            ┆            ┆       ┆   ┆            ┆            ┆        ┆            │
# │ …          ┆            ┆            ┆       ┆   ┆            ┆            ┆        ┆            │
# │ c00c8cba-b ┆ Moorbekstr ┆ Nordersted ┆ 22846 ┆ … ┆ 75         ┆ 90         ┆ dh     ┆ district   │
# │ 6de-4c10-8 ┆ aße 29     ┆ t          ┆       ┆   ┆            ┆            ┆        ┆ heating    │
# │ 9c0-e92312 ┆            ┆            ┆       ┆   ┆            ┆            ┆        ┆            │
# │ …          ┆            ┆            ┆       ┆   ┆            ┆            ┆        ┆            │
# │ 7bdbc8ee-0 ┆ Moorbekstr ┆ Nordersted ┆ 22846 ┆ … ┆ 75         ┆ 90         ┆ dh     ┆ district   │
# │ 0fb-4795-9 ┆ aße 31     ┆ t          ┆       ┆   ┆            ┆            ┆        ┆ heating    │
# │ 9cb-c1739f ┆            ┆            ┆       ┆   ┆            ┆            ┆        ┆            │
# │ …          ┆            ┆            ┆       ┆   ┆            ┆            ┆        ┆            │
# │ d00d6502-a ┆ Moorbekstr ┆ Nordersted ┆ 22846 ┆ … ┆ 75         ┆ 90         ┆ dh     ┆ district   │
# │ 08d-45df-9 ┆ aße 17     ┆ t          ┆       ┆   ┆            ┆            ┆        ┆ heating    │
# │ 9e3-7d8cd5 ┆            ┆            ┆       ┆   ┆            ┆            ┆        ┆            │
# │ …          ┆            ┆            ┆       ┆   ┆            ┆            ┆        ┆            │
# │ …          ┆ …          ┆ …          ┆ …     ┆ … ┆ …          ┆ …          ┆ …      ┆ …          │
# │ 82a01deb-7 ┆ Waldstraße ┆ Nordersted ┆ 22846 ┆ … ┆ 75         ┆ 90         ┆ dh     ┆ district   │
# │ c9d-4e87-a ┆ 81         ┆ t          ┆       ┆   ┆            ┆            ┆        ┆ heating    │
# │ 79a-4693bd ┆            ┆            ┆       ┆   ┆            ┆            ┆        ┆            │
# │ …          ┆            ┆            ┆       ┆   ┆            ┆            ┆        ┆            │
# │ cae17ef4-c ┆ Hasenstieg ┆ Nordersted ┆ 22846 ┆ … ┆ 75         ┆ 90         ┆ dh     ┆ district   │
# │ fad-4446-8 ┆ 13         ┆ t          ┆       ┆   ┆            ┆            ┆        ┆ heating    │
# │ b09-3cf946 ┆            ┆            ┆       ┆   ┆            ┆            ┆        ┆            │
# │ …          ┆            ┆            ┆       ┆   ┆            ┆            ┆        ┆            │
# │ a9644794-4 ┆ Kielort 25 ┆ Nordersted ┆ 22850 ┆ … ┆ 75         ┆ 90         ┆ dh     ┆ district   │
# │ 39b-401c-b ┆            ┆ t          ┆       ┆   ┆            ┆            ┆        ┆ heating    │
# │ 879-8c0225 ┆            ┆            ┆       ┆   ┆            ┆            ┆        ┆            │
# │ …          ┆            ┆            ┆       ┆   ┆            ┆            ┆        ┆            │
# │ 561a9d67-5 ┆ Segeberger ┆ Nordersted ┆ 22850 ┆ … ┆ 75         ┆ 90         ┆ dh     ┆ district   │
# │ 802-4a54-a ┆ Chaussee   ┆ t          ┆       ┆   ┆            ┆            ┆        ┆ heating    │
# │ e7d-0a7822 ┆ 104b       ┆            ┆       ┆   ┆            ┆            ┆        ┆            │
# │ …          ┆            ┆            ┆       ┆   ┆            ┆            ┆        ┆            │
# │ fb5cc271-a ┆ Moorbekstr ┆ Nordersted ┆ 22846 ┆ … ┆ 75         ┆ 90         ┆ dh     ┆ district   │
# │ e15-4f24-b ┆ aße 33     ┆ t          ┆       ┆   ┆            ┆            ┆        ┆ heating    │
# │ 9d5-30782b ┆            ┆            ┆       ┆   ┆            ┆            ┆        ┆            │
# │ …          ┆            ┆            ┆       ┆   ┆            ┆            ┆        ┆            │
# └────────────┴────────────┴────────────┴───────┴───┴────────────┴────────────┴────────┴────────────┘

# %% [markdown]
# ### Merge

# %%
kinergy_meta.schema
# Out:
# Schema([('id', String),
#         ('ort', String),
#         ('adresse', String),
#         ('plz', String),
#         ('anzahlwhg', Int64),
#         ('typ', String),
#         ('complexity', Int64),
#         ('complexity_score', Float64),
#         ('primary_energy', String),
#         ('heated_area', Float64),
#         ('renewable_energy_used', Boolean),
#         ('has_pwh', Boolean),
#         ('pwh_type', String),
#         ('netz_nummer', Int64),
#         ('min_vorlauf_temp', String),
#         ('max_vorlauf_temp', String),
#         ('source', String)])

# %%
leg_data_meta.schema
# Out:
# Schema([('id', String),
#         ('ort', String),
#         ('adresse', String),
#         ('plz', String),
#         ('primary_energy', String),
#         ('heated_area', Float64),
#         ('anzlwhg', Int64),
#         ('co2koeffizient', Float64),
#         ('typ', String),
#         ('source', String)])

# %%
dh_meta.schema
# Out:
# Schema([('id', String),
#         ('adresse', String),
#         ('ort', String),
#         ('plz', String),
#         ('typ', String),
#         ('min_vorlauf_temp', String),
#         ('max_vorlauf_temp', String),
#         ('source', String),
#         ('primary_energy', String)])

# %%
df_meta = pl.concat([leg_data_meta, kinergy_meta, dh_meta], how="diagonal")
df_meta
# Out:
# shape: (139, 18)
# ┌────────────┬────────────┬────────────┬───────┬───┬──────────┬────────────┬───────────┬───────────┐
# │ id         ┆ ort        ┆ adresse    ┆ plz   ┆ … ┆ pwh_type ┆ netz_numme ┆ min_vorla ┆ max_vorla │
# │ ---        ┆ ---        ┆ ---        ┆ ---   ┆   ┆ ---      ┆ r          ┆ uf_temp   ┆ uf_temp   │
# │ str        ┆ str        ┆ str        ┆ str   ┆   ┆ str      ┆ ---        ┆ ---       ┆ ---       │
# │            ┆            ┆            ┆       ┆   ┆          ┆ i64        ┆ str       ┆ str       │
# ╞════════════╪════════════╪════════════╪═══════╪═══╪══════════╪════════════╪═══════════╪═══════════╡
# │ 400308PVG  ┆ Hamburg    ┆ Martinistr ┆ 20251 ┆ … ┆ null     ┆ null       ┆ null      ┆ null      │
# │            ┆            ┆ aße 44     ┆       ┆   ┆          ┆            ┆           ┆           │
# │ 400690GVG  ┆ Hamburg    ┆ Op´n       ┆ 22589 ┆ … ┆ null     ┆ null       ┆ null      ┆ null      │
# │            ┆            ┆ Hainholt   ┆       ┆   ┆          ┆            ┆           ┆           │
# │            ┆            ┆ 4-18       ┆       ┆   ┆          ┆            ┆           ┆           │
# │ 400356PVG  ┆ Elmshorn   ┆ Fehrsstraß ┆ 25336 ┆ … ┆ null     ┆ null       ┆ null      ┆ null      │
# │            ┆            ┆ e 7        ┆       ┆   ┆          ┆            ┆           ┆           │
# │ 400131GVG  ┆ Lübeck     ┆ Brandenbau ┆ 23566 ┆ … ┆ null     ┆ null       ┆ null      ┆ null      │
# │            ┆            ┆ mer        ┆       ┆   ┆          ┆            ┆           ┆           │
# │            ┆            ┆ Landstraße ┆       ┆   ┆          ┆            ┆           ┆           │
# │            ┆            ┆ 177        ┆       ┆   ┆          ┆            ┆           ┆           │
# │ 4008231VG  ┆ Hamburg    ┆ Tinnumer   ┆ 22117 ┆ … ┆ null     ┆ null       ┆ null      ┆ null      │
# │            ┆            ┆ Weg 1-9,   ┆       ┆   ┆          ┆            ┆           ┆           │
# │            ┆            ┆ Morsumer   ┆       ┆   ┆          ┆            ┆           ┆           │
# │            ┆            ┆ Weg…       ┆       ┆   ┆          ┆            ┆           ┆           │
# │ …          ┆ …          ┆ …          ┆ …     ┆ … ┆ …        ┆ …          ┆ …         ┆ …         │
# │ 82a01deb-7 ┆ Nordersted ┆ Waldstraße ┆ 22846 ┆ … ┆ null     ┆ null       ┆ 75        ┆ 90        │
# │ c9d-4e87-a ┆ t          ┆ 81         ┆       ┆   ┆          ┆            ┆           ┆           │
# │ 79a-4693bd ┆            ┆            ┆       ┆   ┆          ┆            ┆           ┆           │
# │ …          ┆            ┆            ┆       ┆   ┆          ┆            ┆           ┆           │
# │ cae17ef4-c ┆ Nordersted ┆ Hasenstieg ┆ 22846 ┆ … ┆ null     ┆ null       ┆ 75        ┆ 90        │
# │ fad-4446-8 ┆ t          ┆ 13         ┆       ┆   ┆          ┆            ┆           ┆           │
# │ b09-3cf946 ┆            ┆            ┆       ┆   ┆          ┆            ┆           ┆           │
# │ …          ┆            ┆            ┆       ┆   ┆          ┆            ┆           ┆           │
# │ a9644794-4 ┆ Nordersted ┆ Kielort 25 ┆ 22850 ┆ … ┆ null     ┆ null       ┆ 75        ┆ 90        │
# │ 39b-401c-b ┆ t          ┆            ┆       ┆   ┆          ┆            ┆           ┆           │
# │ 879-8c0225 ┆            ┆            ┆       ┆   ┆          ┆            ┆           ┆           │
# │ …          ┆            ┆            ┆       ┆   ┆          ┆            ┆           ┆           │
# │ 561a9d67-5 ┆ Nordersted ┆ Segeberger ┆ 22850 ┆ … ┆ null     ┆ null       ┆ 75        ┆ 90        │
# │ 802-4a54-a ┆ t          ┆ Chaussee   ┆       ┆   ┆          ┆            ┆           ┆           │
# │ e7d-0a7822 ┆            ┆ 104b       ┆       ┆   ┆          ┆            ┆           ┆           │
# │ …          ┆            ┆            ┆       ┆   ┆          ┆            ┆           ┆           │
# │ fb5cc271-a ┆ Nordersted ┆ Moorbekstr ┆ 22846 ┆ … ┆ null     ┆ null       ┆ 75        ┆ 90        │
# │ e15-4f24-b ┆ t          ┆ aße 33     ┆       ┆   ┆          ┆            ┆           ┆           │
# │ 9d5-30782b ┆            ┆            ┆       ┆   ┆          ┆            ┆           ┆           │
# │ …          ┆            ┆            ┆       ┆   ┆          ┆            ┆           ┆           │
# └────────────┴────────────┴────────────┴───────┴───┴──────────┴────────────┴───────────┴───────────┘

# %%
df_meta.describe()
# Out:
# shape: (9, 19)
# ┌───────────┬───────────┬──────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ statistic ┆ id        ┆ ort      ┆ adresse   ┆ … ┆ pwh_type  ┆ netz_numm ┆ min_vorla ┆ max_vorla │
# │ ---       ┆ ---       ┆ ---      ┆ ---       ┆   ┆ ---       ┆ er        ┆ uf_temp   ┆ uf_temp   │
# │ str       ┆ str       ┆ str      ┆ str       ┆   ┆ str       ┆ ---       ┆ ---       ┆ ---       │
# │           ┆           ┆          ┆           ┆   ┆           ┆ f64       ┆ str       ┆ str       │
# ╞═══════════╪═══════════╪══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ count     ┆ 139       ┆ 139      ┆ 139       ┆ … ┆ 16        ┆ 4.0       ┆ 94        ┆ 94        │
# │ null_coun ┆ 0         ┆ 0        ┆ 0         ┆ … ┆ 123       ┆ 135.0     ┆ 45        ┆ 45        │
# │ t         ┆           ┆          ┆           ┆   ┆           ┆           ┆           ┆           │
# │ mean      ┆ null      ┆ null     ┆ null      ┆ … ┆ null      ┆ 2475.25   ┆ null      ┆ null      │
# │ std       ┆ null      ┆ null     ┆ null      ┆ … ┆ null      ┆ 250.16711 ┆ null      ┆ null      │
# │           ┆           ┆          ┆           ┆   ┆           ┆ 1         ┆           ┆           │
# │ min       ┆ 0c9ad311- ┆ Bamberg  ┆ Alter Spo ┆ … ┆ central   ┆ 2100.0    ┆  80 °C    ┆  135 °C   │
# │           ┆ b86f-4371 ┆          ┆ rtplatz   ┆   ┆           ┆           ┆           ┆           │
# │           ┆ -a695-512 ┆          ┆ 1-5       ┆   ┆           ┆           ┆           ┆           │
# │           ┆ ca4…      ┆          ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 25%       ┆ null      ┆ null     ┆ null      ┆ … ┆ null      ┆ 2600.0    ┆ null      ┆ null      │
# │ 50%       ┆ null      ┆ null     ┆ null      ┆ … ┆ null      ┆ 2600.0    ┆ null      ┆ null      │
# │ 75%       ┆ null      ┆ null     ┆ null      ┆ … ┆ null      ┆ 2600.0    ┆ null      ┆ null      │
# │ max       ┆ fb684f25- ┆ Würzburg ┆ Wilhelmst ┆ … ┆ decentral ┆ 2601.0    ┆ 75        ┆ 90        │
# │           ┆ a63d-4d3e ┆          ┆ raße      ┆   ┆           ┆           ┆           ┆           │
# │           ┆ -9277-6d7 ┆          ┆ 33-41     ┆   ┆           ┆           ┆           ┆           │
# │           ┆ 59b…      ┆          ┆           ┆   ┆           ┆           ┆           ┆           │
# └───────────┴───────────┴──────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘
