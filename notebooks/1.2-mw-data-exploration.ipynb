# %% [markdown]
# # Hourly Values and Weather Data

# %% [markdown]
# ## Load data daily and hourly

# %%
from src.energy_forecast.config import PROCESSED_DATA_DIR, INTERIM_DATA_DIR, META_DIR, REPORTS_DIR
import polars as pl

dataset_hourly_csv_ = PROCESSED_DATA_DIR / "dataset_hourly_feat.csv"
df_hourly = pl.read_csv(dataset_hourly_csv_)
len(df_hourly)
# Out:
# 688766

# %%
dataset_daily_csv_ = PROCESSED_DATA_DIR / "dataset_daily_feat.csv"
df_daily = pl.read_csv(dataset_daily_csv_)
len(df_daily)
# Out:
# 101646

# %%
from src.energy_forecast.config import META_DIR

data_df = data_df.with_columns(
        pl.coalesce(data_df.join(pl.read_csv(META_DIR / "kinergy_meta.csv"), on="id", how="left")["plz"],
                    data_df.join(pl.read_csv(META_DIR / "legacy_meta.csv"), on="id", how="left")["plz"],
                    data_df.join(pl.read_csv(META_DIR / "dh_meta.csv").rename({"postal_code": "plz"}),
                                 on="id", how="left")["plz"],
                    ).str.strip_chars())
len(data_df)
# Out:
# 688766

# %% [markdown]
# ## Data Sources

# %%
data_df.group_by(pl.col("source")).agg(pl.len())
# Out:
# shape: (2, 2)
# ┌─────────┬────────┐
# │ source  ┆ len    │
# │ ---     ┆ ---    │
# │ str     ┆ u32    │
# ╞═════════╪════════╡
# │ kinergy ┆ 163665 │
# │ dh      ┆ 525101 │
# └─────────┴────────┘

# %%
city_df = data_df.group_by(pl.col("plz")).agg(pl.col("datetime").min().alias("min_date"),
                                                  pl.col("datetime").max().alias("max_date"))
city_df
# Out:
# shape: (14, 3)
# ┌───────┬────────────────────────────┬────────────────────────────┐
# │ plz   ┆ min_date                   ┆ max_date                   │
# │ ---   ┆ ---                        ┆ ---                        │
# │ str   ┆ str                        ┆ str                        │
# ╞═══════╪════════════════════════════╪════════════════════════════╡
# │ 22844 ┆ 2022-08-23T08:00:00.000000 ┆ 2025-04-22T11:00:00.000000 │
# │ 22419 ┆ 2021-10-04T10:00:00.000000 ┆ 2023-09-21T10:00:00.000000 │
# │ 10249 ┆ 2022-10-19T13:00:00.000000 ┆ 2023-09-13T10:00:00.000000 │
# │ 20539 ┆ 2022-01-24T13:00:00.000000 ┆ 2023-09-21T08:00:00.000000 │
# │ 91054 ┆ 2021-08-13T13:00:00.000000 ┆ 2023-09-18T15:00:00.000000 │
# │ …     ┆ …                          ┆ …                          │
# │ 12681 ┆ 2023-01-01T01:00:00.000000 ┆ 2023-09-09T14:00:00.000000 │
# │ 97084 ┆ 2021-07-08T15:00:00.000000 ┆ 2023-07-07T00:00:00.000000 │
# │ 97074 ┆ 2021-05-06T14:00:00.000000 ┆ 2023-09-13T06:00:00.000000 │
# │ 95447 ┆ 2021-08-13T13:00:00.000000 ┆ 2023-01-31T09:00:00.000000 │
# │ 97082 ┆ 2022-04-04T13:00:00.000000 ┆ 2023-09-12T15:00:00.000000 │
# └───────┴────────────────────────────┴────────────────────────────┘

# %%
from src.energy_forecast.config import FEATURES_DIR

weather_df = pl.read_csv(FEATURES_DIR / "weather_hourly.csv")
weather_df
# Out:
# shape: (212_154, 13)
# ┌───────────────────────────────┬──────┬──────┬──────┬───┬────────┬──────┬──────┬───────┐
# │ time                          ┆ temp ┆ dwpt ┆ rhum ┆ … ┆ pres   ┆ tsun ┆ coco ┆ plz   │
# │ ---                           ┆ ---  ┆ ---  ┆ ---  ┆   ┆ ---    ┆ ---  ┆ ---  ┆ ---   │
# │ str                           ┆ f64  ┆ f64  ┆ f64  ┆   ┆ f64    ┆ f64  ┆ f64  ┆ i64   │
# ╞═══════════════════════════════╪══════╪══════╪══════╪═══╪════════╪══════╪══════╪═══════╡
# │ 2022-08-23T06:00:00.000000000 ┆ 18.1 ┆ 13.4 ┆ 74.0 ┆ … ┆ 1018.0 ┆ 15.0 ┆ 4.0  ┆ 22846 │
# │ 2022-08-23T07:00:00.000000000 ┆ 20.1 ┆ 14.0 ┆ 68.0 ┆ … ┆ 1018.3 ┆ 6.0  ┆ 4.0  ┆ 22846 │
# │ 2022-08-23T08:00:00.000000000 ┆ 22.3 ┆ 13.4 ┆ 57.0 ┆ … ┆ 1018.3 ┆ 60.0 ┆ 3.0  ┆ 22846 │
# │ 2022-08-23T09:00:00.000000000 ┆ 24.1 ┆ 13.3 ┆ 51.0 ┆ … ┆ 1018.6 ┆ 60.0 ┆ 1.0  ┆ 22846 │
# │ 2022-08-23T10:00:00.000000000 ┆ 24.5 ┆ 13.4 ┆ 50.0 ┆ … ┆ 1018.5 ┆ 60.0 ┆ 1.0  ┆ 22846 │
# │ …                             ┆ …    ┆ …    ┆ …    ┆ … ┆ …      ┆ …    ┆ …    ┆ …     │
# │ 2023-09-17T13:00:00.000000000 ┆ 26.4 ┆ 13.5 ┆ 45.0 ┆ … ┆ 1015.9 ┆ 60.0 ┆ 4.0  ┆ 10963 │
# │ 2023-09-17T14:00:00.000000000 ┆ 26.3 ┆ 13.8 ┆ 46.0 ┆ … ┆ 1015.6 ┆ 60.0 ┆ 4.0  ┆ 10963 │
# │ 2023-09-17T15:00:00.000000000 ┆ 26.7 ┆ 13.8 ┆ 45.0 ┆ … ┆ 1015.3 ┆ 60.0 ┆ 3.0  ┆ 10963 │
# │ 2023-09-17T16:00:00.000000000 ┆ 26.2 ┆ 14.3 ┆ 48.0 ┆ … ┆ 1015.2 ┆ 60.0 ┆ 1.0  ┆ 10963 │
# │ 2023-09-17T17:00:00.000000000 ┆ 24.2 ┆ 13.7 ┆ 52.0 ┆ … ┆ 1015.1 ┆ 32.0 ┆ 1.0  ┆ 10963 │
# └───────────────────────────────┴──────┴──────┴──────┴───┴────────┴──────┴──────┴───────┘

# %%
df = pl.read_csv(PROCESSED_DATA_DIR / "dataset_hourly_feat.csv")
df
# Out:
# shape: (688_766, 27)
# ┌─────────────────────────┬─────────────────────────┬───────┬─────┬───┬──────┬──────┬───────┬──────┐
# │ id                      ┆ datetime                ┆ diff  ┆ typ ┆ … ┆ temp ┆ dwpt ┆ rhum  ┆ coco │
# │ ---                     ┆ ---                     ┆ ---   ┆ --- ┆   ┆ ---  ┆ ---  ┆ ---   ┆ ---  │
# │ str                     ┆ str                     ┆ f64   ┆ i64 ┆   ┆ f64  ┆ f64  ┆ f64   ┆ f64  │
# ╞═════════════════════════╪═════════════════════════╪═══════╪═════╪═══╪══════╪══════╪═══════╪══════╡
# │ 83758fff-e013-11eb-9d61 ┆ 2022-01-24T13:00:00.000 ┆ 293.8 ┆ 2   ┆ … ┆ 5.2  ┆ 1.9  ┆ 79.0  ┆ 4.0  │
# │ -02b402…                ┆ 000000                  ┆       ┆     ┆   ┆      ┆      ┆       ┆      │
# │ 83758fff-e013-11eb-9d61 ┆ 2022-01-24T14:00:00.000 ┆ 282.5 ┆ 2   ┆ … ┆ 5.0  ┆ 1.8  ┆ 80.0  ┆ 4.0  │
# │ -02b402…                ┆ 000000                  ┆       ┆     ┆   ┆      ┆      ┆       ┆      │
# │ 83758fff-e013-11eb-9d61 ┆ 2022-01-24T15:00:00.000 ┆ 180.8 ┆ 2   ┆ … ┆ 5.0  ┆ 1.3  ┆ 77.0  ┆ 4.0  │
# │ -02b402…                ┆ 000000                  ┆       ┆     ┆   ┆      ┆      ┆       ┆      │
# │ 83758fff-e013-11eb-9d61 ┆ 2022-01-24T16:00:00.000 ┆ 192.1 ┆ 2   ┆ … ┆ 4.7  ┆ 1.4  ┆ 79.0  ┆ 4.0  │
# │ -02b402…                ┆ 000000                  ┆       ┆     ┆   ┆      ┆      ┆       ┆      │
# │ 83758fff-e013-11eb-9d61 ┆ 2022-01-24T17:00:00.000 ┆ 79.1  ┆ 2   ┆ … ┆ 4.5  ┆ 0.8  ┆ 77.0  ┆ 4.0  │
# │ -02b402…                ┆ 000000                  ┆       ┆     ┆   ┆      ┆      ┆       ┆      │
# │ …                       ┆ …                       ┆ …     ┆ …   ┆ … ┆ …    ┆ …    ┆ …     ┆ …    │
# │ cae17ef4-cfad-4446-8b09 ┆ 2025-04-20T13:00:00.000 ┆ 75.0  ┆ 2   ┆ … ┆ 9.7  ┆ 7.0  ┆ 83.0  ┆ 4.0  │
# │ -3cf946…                ┆ 000000                  ┆       ┆     ┆   ┆      ┆      ┆       ┆      │
# │ cae17ef4-cfad-4446-8b09 ┆ 2025-04-20T14:00:00.000 ┆ 41.0  ┆ 2   ┆ … ┆ 10.6 ┆ 6.9  ┆ 78.0  ┆ 4.0  │
# │ -3cf946…                ┆ 000000                  ┆       ┆     ┆   ┆      ┆      ┆       ┆      │
# │ cae17ef4-cfad-4446-8b09 ┆ 2025-04-21T02:00:00.000 ┆ 23.0  ┆ 2   ┆ … ┆ 2.5  ┆ 2.5  ┆ 100.0 ┆ 4.0  │
# │ -3cf946…                ┆ 000000                  ┆       ┆     ┆   ┆      ┆      ┆       ┆      │
# │ cae17ef4-cfad-4446-8b09 ┆ 2025-04-21T14:00:00.000 ┆ 42.0  ┆ 2   ┆ … ┆ 15.8 ┆ 9.0  ┆ 64.0  ┆ 4.0  │
# │ -3cf946…                ┆ 000000                  ┆       ┆     ┆   ┆      ┆      ┆       ┆      │
# │ cae17ef4-cfad-4446-8b09 ┆ 2025-04-22T10:00:00.000 ┆ 98.0  ┆ 2   ┆ … ┆ 15.7 ┆ 10.5 ┆ 71.0  ┆ 4.0  │
# │ -3cf946…                ┆ 000000                  ┆       ┆     ┆   ┆      ┆      ┆       ┆      │
# └─────────────────────────┴─────────────────────────┴───────┴─────┴───┴──────┴──────┴───────┴──────┘

# %%
df.group_by(["primary_energy"]).agg(pl.len())
# Out:
# shape: (2, 2)
# ┌──────────────────┬────────┐
# │ primary_energy   ┆ len    │
# │ ---              ┆ ---    │
# │ str              ┆ u32    │
# ╞══════════════════╪════════╡
# │ gas              ┆ 127381 │
# │ district heating ┆ 561385 │
# └──────────────────┴────────┘

# %%
df_kinergy_hourly = pl.read_csv(INTERIM_DATA_DIR / "kinergy_hourly.csv")
df_kinergy_meta = pl.read_csv(META_DIR / "kinergy_meta.csv")
df_kinergy_hourly.join(df_kinergy_meta, on="id", how="left").group_by(["primary_energy"]).agg(pl.len())
# Out:
# shape: (2, 2)
# ┌──────────────────┬────────┐
# │ primary_energy   ┆ len    │
# │ ---              ┆ ---    │
# │ str              ┆ u32    │
# ╞══════════════════╪════════╡
# │ gas              ┆ 128697 │
# │ district heating ┆ 40137  │
# └──────────────────┴────────┘

# %%
df_kinergy_daily = pl.read_csv(INTERIM_DATA_DIR / "kinergy_daily.csv")
df_kinergy_daily.join(df_kinergy_meta, on="id", how="left").group_by(["primary_energy"]).agg(pl.len())
# Out:
# shape: (2, 2)
# ┌──────────────────┬──────┐
# │ primary_energy   ┆ len  │
# │ ---              ┆ ---  │
# │ str              ┆ u32  │
# ╞══════════════════╪══════╡
# │ district heating ┆ 1694 │
# │ gas              ┆ 5434 │
# └──────────────────┴──────┘

# %% [markdown]
# ## Time span for each sensor

# %%
import plotly.graph_objs as go

df_min_max_dates = df_hourly.group_by(["id"]).agg(
    [pl.col("datetime").min().alias("min_date"),
     pl.col("datetime").max().alias("max_date"),
     pl.len().alias("days")
     ]
)

fig = go.Figure()
for (start, end, value, days) in zip(df_min_max_dates["min_date"], df_min_max_dates["max_date"],
                                     df_min_max_dates["id"], df_min_max_dates["days"]):
    # name = f"{start} to {end}"
    name = days
    fig.add_trace(go.Scatter(x=[start, end], y=[value, value],
                             mode='lines', name=name))

fig.update_layout(
    title = "Data Spans for Hourly Time-series",
    title_x = 0.5
)
fig.update_yaxes(visible=False, showticklabels=False)
fig.update_layout(showlegend=False, template="plotly")

fig.show()
# fig.write_html("../reports/figures/gaszähler_start_end_datum.html")
fig.write_image("../reports/figures/hourly_time_span.png")
# Out:
# <div>                            <div id="e9c9955f-d817-4ca0-849f-132897cad2f7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e9c9955f-d817-4ca0-849f-132897cad2f7")) {                    Plotly.newPlot(                        "e9c9955f-d817-4ca0-849f-132897cad2f7",                        [{"mode":"lines","name":"11829","x":["2022-08-23T17:00:00.000000000","2025-04-22T09:00:00.000000000"],"y":["c00c8cba-b6de-4c10-89c0-e923127acc4e.71758690flyq","c00c8cba-b6de-4c10-89c0-e923127acc4e.71758690flyq"],"type":"scatter"},{"mode":"lines","name":"10687","x":["2022-10-01T16:00:00.000000000","2025-04-22T11:00:00.000000000"],"y":["8ff79953-ad51-40b5-a025-f24418cae4b1.03216e0fhbqi","8ff79953-ad51-40b5-a025-f24418cae4b1.03216e0fhbqi"],"type":"scatter"},{"mode":"lines","name":"1454","x":["2022-09-30T13:00:00.000000000","2023-07-14T06:00:00.000000000"],"y":["33920b20-2ae7-4e6b-912b-5fc4294d6ed5.40376b9by1qk","33920b20-2ae7-4e6b-912b-5fc4294d6ed5.40376b9by1qk"
     pl.len().alias("days")
     ]
)

fig = go.Figure()
for (start, end, value, days) in zip(df_min_max_dates["min_date"], df_min_max_dates["max_date"],
                                     df_min_max_dates["id"], df_min_max_dates["days"]):
    # name = f"{start} to {end}"
    name = days
    fig.add_trace(go.Scatter(x=[start, end], y=[value, value],
                             mode='lines', name=name))

fig.update_layout(
    title = "Data Spans for Daily Time-series",
    title_x = 0.5
)
fig.update_yaxes(visible=False, showticklabels=False)
fig.update_layout(showlegend=False, template="plotly")
fig.show()
# fig.write_html("../reports/figures/gaszähler_start_end_datum.html")
fig.write_image("../reports/figures/daily_time_span.png")
# Out:
# <div>                            <div id="f390a611-fbe0-4e14-87a7-e26c2d24611a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f390a611-fbe0-4e14-87a7-e26c2d24611a")) {                    Plotly.newPlot(                        "f390a611-fbe0-4e14-87a7-e26c2d24611a",                        [{"mode":"lines","name":"1118","x":["2018-12-12T00:00:00.000000000","2022-01-17T00:00:00.000000000"],"y":["400352PVG","400352PVG"],"type":"scatter"},{"mode":"lines","name":"606","x":["2022-01-24T00:00:00.000000000","2023-09-21T00:00:00.000000000"],"y":["83758fff-e013-11eb-9d61-02b402f0c1de","83758fff-e013-11eb-9d61-02b402f0c1de"],"type":"scatter"},{"mode":"lines","name":"564","x":["2020-08-19T00:00:00.000000000","2022-03-16T00:00:00.000000000"],"y":["400451GVG","400451GVG"],"type":"scatter"},{"mode":"lines","name":"122","x":["2021-05-09T00:00:00.000000000","2021-10-04T00:00:00.000000000"],"y":["400884GVG","400884GVG"],"type":"scatter"},{"mode":"lines","name":"713","x":["2021-07-08T00:00:00.000000000","2023-07-07T00:00:00.000000000"],"y":["6abb785c-dfff-11eb-9d61-02b402f0c1de","6abb785c-dfff-11eb-9d61-02b402f0c1de"],"type":"scatter"},{"mode":"lines","name":"337","x":["2021-03-20T00:00:00.000000000","2022-03-16T00:00:00.000000000"],"y":["400458GVG","400458GVG"],"type":"scatter"},{"mode":"lines","name":"851","x":["2021-05-06T00:00:00.000000000","2023-09-13T00:00:00.000000000"],"y":["730285cc-ae67-11eb-9b5e-02b402f0c1de","730285cc-ae67-11eb-9b5e-02b402f0c1de"],"type":"scatter"},{"mode":"lines","name":"194","x":["2022-10-01T00:00:00.000000000","2023-07-06T00:00:00.000000000"],"y":["2b9a3bc7-252f-4a10-8ccb-5ccce53e896a.4e83b354elou","2b9a3bc7-252f-4a10-8ccb-5ccce53e896a.4e83b354elou"],"type":"scatter"},{"mode":"lines","name":"780","x":["2021-07-08T00:00:00.000000000","2023-09-12T00:00:00.000000000"],"y":["bf254b46-e009-11eb-9d61-02b402f0c1de","bf254b46-e009-11eb-9d61-02b402f0c1de"],"type":"scatter"},{"mode":"lines","name":"1178","x":["2018-11-22T00:00:00.000000000","2022-04-04T00:00:00.000000000"],"y":["400338PVG","400338PVG"],"type":"scatter"},{"mode":"lines","name":"1279","x":["2018-09-12T00:00:00.000000000","2022-03-24T00:00:00.000000000"],"y":["400055GVG","400055GVG"],"type":"scatter"},{"mode":"lines","name":"220","x":["2022-10-01T00:00:00.000000000","2023-07-14T00:00:00.000000000"],"y":["33920b20-2ae7-4e6b-912b-5fc4294d6ed5.40376b9by1qk","33920b20-2ae7-4e6b-912b-5fc4294d6ed5.40376b9by1qk"],"type":"scatter"},{"mode":"lines","name":"225","x":["2021-05-31T00:00:00.000000000","2022-01-17T00:00:00.000000000"],"y":["400853GVG","400853GVG"],"type":"scatter"},{"mode":"lines","name":"858","x":["2022-10-02T00:00:00.000000000","2025-04-22T00:00:00.000000000"],"y":["61470655-33c1-4717-b729-baa6658a6aeb.316e91eff2ic","61470655-33c1-4717-b729-baa6658a6aeb.316e91eff2ic"],"type":"scatter"},{"mode":"lines","name":"933","x":["2022-08-24T00:00:00.000000000","2025-04-22T00:00:00.000000000"],"y":["2a5d5a37-a843-4621-b20a-a0c1a5e42e49.dc62aac1q9uf","2a5d5a37-a843-4621-b20a-a0c1a5e42e49.dc62aac1q9uf"],"type":"scatter"},{"mode":"lines","name":"469","x":["2020-07-01T00:00:00.000000000","2022-03-16T00:00:00.000000000"],"y":["400711GVG","400711GVG"],"type":"scatter"},{"mode":"lines","name":"937","x":["2022-08-24T00:00:00.000000000","2025-04-22T00:00:00.000000000"],"y":["d4847556-40f8-4940-b21d-3390fe2c2547.123c86efkcrg","d4847556-40f8-4940-b21d-3390fe2c2547.123c86efkcrg"],"type":"scatter"},{"mode":"lines","name":"577","x":["2020-08-08T00:00:00.000000000","2022-03-16T00:00:00.000000000"],"y":["400731GVG","400731GVG"],"type":"scatter"},{"mode":"lines","name":"876","x":["2022-10-01T00:00:00.000000000","2025-04-22T00:00:00.000000000"],"y":["72013db2-014c-4c4f-8eee-ce179b77ba6f.b21844a2dbvi","72013db2-014c-4c4f-8eee-ce179b77ba6f.b21844a2db ...

# %% [markdown]
# ## Outlier Detection - plot outlier

# %%
from src.energy_forecast.dataset import Dataset

ds = Dataset(res="daily")
ds.create()
# Out:
# 2025-06-09 21:29:34.709500: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-06-09 21:29:34.744156: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1749497374.786861 1684895 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1749497374.800237 1684895 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1749497374.831195 1684895 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1749497374.831236 1684895 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1749497374.831242 1684895 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1749497374.831245 1684895 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-06-09 21:29:34.840748: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-06-09 21:29:38.923 | INFO     | src.energy_forecast.dataset:create:46 - Creating daily dataset
# 2025-06-09 21:29:38.953 | INFO     | src.energy_forecast.dataset:create:51 - Number of rows: 110005
# 2025-06-09 21:29:38.974 | INFO     | src.energy_forecast.dataset:create:53 - Number of sensors: 142

# %%
sensor_id = "a0bb40c4-7d73-4c5d-91bd-d82fe748a75d.74820f614mer"
df_s = ds.df.filter(pl.col("id") == sensor_id)
df_s = df_s.select(["id", "datetime", "diff"])
df_s
# Out:
# shape: (902, 3)
# ┌─────────────────────────────────┬────────────────────────────┬───────┐
# │ id                              ┆ datetime                   ┆ diff  │
# │ ---                             ┆ ---                        ┆ ---   │
# │ str                             ┆ str                        ┆ f64   │
# ╞═════════════════════════════════╪════════════════════════════╪═══════╡
# │ a0bb40c4-7d73-4c5d-91bd-d82fe7… ┆ 2022-08-24T00:00:00.000000 ┆ 491.0 │
# │ a0bb40c4-7d73-4c5d-91bd-d82fe7… ┆ 2022-08-25T00:00:00.000000 ┆ 489.0 │
# │ a0bb40c4-7d73-4c5d-91bd-d82fe7… ┆ 2022-08-26T00:00:00.000000 ┆ 417.0 │
# │ a0bb40c4-7d73-4c5d-91bd-d82fe7… ┆ 
2022-10-26T00:00:00.000000","2022-10-27T00:00:00.000000","2022-10-28T00:00:00.000000","2022-10-29T00:00:00.000000","2022-10-30T00:00:00.000000","2022-10-31T00:00:00.000000","2022-11-01T00:00:00.000000","2022-11-02T00:00:00.000000","2022-11-03T00:00:00.000000","2022-11-04T00:00:00.000000","2022-11-05T00:00:00.000000","2022-11-06T00:00:00.000000","2022-11-07T00:00:00.000000","2022-11-08T00:00:00.000000","2022-11-09T00:00:00.000000","2022-11-10T00:00:00.000000","2022-11-11T00:00:00.000000","2022-11-12T00:00:00.000000","2022-11-13T00:00:00.000000","2022-11-14T00:00:00.000000","2022-11-15T00:00:00.000000","2022-11-16T00:00:00.000000","2022-11-17T00:00:00.000000","2022-11-18T00:00:00.000000","2022-11-19T00:00:00.000000","2022-11-20T00:00:00.000000","2022-11-21T00:00:00.000000","2022-11-22T00:00:00.000000","2022-11-23T00:00:00.000000","2022-11-24T00:00:00.000000","2022-11-25T00:00:00.000000","2022-11-26T00:00:00.000000","2022-11-27T00:00:00.000000","2022-11-28T00:00:00.000000","2022-11-29T00:00:00.000000","2022-11-30T00:00:00.000000","2022-12-03T00:00:00.000000","2022-12-04T00:00:00.000000","2022-12-05T00:00:00.000000","2022-12-06T00:00:00.000000","2022-12-07T00:00:00.000000","2022-12-08T00:00:00.000000","2022-12-09T00:00:00.000000","2022-12-10T00:00:00.000000","2022-12-11T00:00:00.000000","2022-12-12T00:00:00.000000","2022-12-13T00:00:00.000000","2022-12-14T00:00:00.000000","2022-12-15T00:00:00. ...

# %%
column = "diff"
q25 = df_s[column].quantile(0.25)
q75 = df_s[column].quantile(0.75)
iqr = q75 - q25

upper_bound = q75 + 1.5 * iqr

filtered_df = df_s.filter(pl.col(column) <= upper_bound)

df_new = df_s.with_columns(~(pl.col("datetime").is_in(filtered_df["datetime"])).alias("outlier"))

fig = px.scatter(df_new, x="datetime", y="diff", color="outlier")
fig.update_layout(template="plotly")
fig.show()
# Out:
# <div>                            <div id="f5eeb681-6373-44fd-90eb-3b603451a493" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f5eeb681-6373-44fd-90eb-3b603451a493")) {                    Plotly.newPlot(                        "f5eeb681-6373-44fd-90eb-3b603451a493",                        [{"hovertemplate":"outlier=False\u003cbr\u003edatetime=%{x}\u003cbr\u003ediff=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"False","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"False","orientation":"v","showlegend":true,"x":["2022-08-24T00:00:00.000000","2022-08-25T00:00:00.000000","2022-08-26T00:00:00.000000","2022-08-27T00:00:00.000000","2022-08-28T00:00:00.000000","2022-08-29T00:00:00.000000","2022-08-30T00:00:00.000000","2022-08-31T00:00:00.000000","2022-09-01T00:00:00.000000","2022-09-02T00:00:00.000000","2022-09-03T00:00:00.000000","2022-09-04T00:00:00.000000","2022-09-05T00:00:00.000000","2022-09-06T00:00:00.000000","2022-09-07T00:00:00.000000","2022-09-08T00:00:00.000000","2022-09-09T00:00:00.000000","2022-09-10T00:00:00.000000","2022-09-11T00:00:00.000000","2022-09-12T00:00:00.000000","2022-09-13T00:00:00.000000","2022-09