# %% [markdown]
# # Data Exploration: Time Spans, Splits, and Interpolation
#
# This notebook explores:
# 1. Daily and hourly data loading
# 2. Time spans for each sensor before and after train/test/val split
# 3. Outlier detection examples
# 4. Data interpolation process (before and after)

# %% [markdown]
# ## Setup and Imports

# %%
import sys
import json
sys.path.insert(0, '..')

from src.energy_forecast.config import (PROCESSED_DATA_DIR, INTERIM_DATA_DIR, META_DIR, REPORTS_DIR, FIGURES_DIR)
from src.energy_forecast.dataset import Dataset, InterpolatedDataset, TrainDatasetBuilding
from src.energy_forecast.utils.train_test_val_split import get_train_test_val_split

import polars as pl
import pandas as pd
import plotly.graph_objs as go
import plotly.express as px
from pathlib import Path

# Set display options
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

FIGURES_DIR.mkdir(parents=True, exist_ok=True)

with open(Path('..') / 'references' / 'notebook_sensor_ids.json') as f:
    SENSOR_IDS = json.load(f)

# %% [markdown]
# ## Load Processed Daily and Hourly Data

# %%
# Load interpolated and feature-engineered datasets
dataset_hourly_csv = PROCESSED_DATA_DIR / "dataset_interpolate_hourly_feat.csv"
df_hourly = pl.read_csv(dataset_hourly_csv)
print(f"Hourly data shape: {df_hourly.shape}")
print(f"Unique sensors (hourly): {df_hourly['id'].n_unique()}")

dataset_daily_csv = PROCESSED_DATA_DIR / "dataset_interpolate_daily_feat.csv"
df_daily = pl.read_csv(dataset_daily_csv)
print(f"\nDaily data shape: {df_daily.shape}")
print(f"Unique sensors (daily): {df_daily['id'].n_unique()}")
# Out:
# Hourly data shape: (834313, 27)
# Unique sensors (hourly): 1125
#
# Daily data shape: (103999, 29)
# Unique sensors (daily): 361

# %% [markdown]
# ## Time Spans for Each Sensor (Before Split)
#
# Visualize the temporal coverage of each sensor in the dataset before any train/test/val splitting.

# %%
# Hourly time spans
df_min_max_dates_hourly = df_hourly.group_by(["id"]).agg(
    [pl.col("datetime").min().alias("min_date"),
     pl.col("datetime").max().alias("max_date"),
     pl.len().alias("num_records")
     ]
)

fig = go.Figure()
for i, (start, end, sensor_id, num_records) in enumerate(zip(
    df_min_max_dates_hourly["min_date"], 
    df_min_max_dates_hourly["max_date"],
    df_min_max_dates_hourly["id"], 
    df_min_max_dates_hourly["num_records"]
)):
    fig.add_trace(go.Scatter(
        x=[start, end], 
        y=[i, i],
        mode='lines',
        name=f"{num_records} records",
        hovertemplate=f"<b>Sensor {i}</b><br>Start: {start}<br>End: {end}<br>Records: {num_records}"
    ))

fig.update_layout(
    title="Hourly Data: Time Spans per Sensor (Before Split)",
    title_x=0.5,
    xaxis_title="Date",
    yaxis_title="Sensor Index",
    showlegend=False,
    template="plotly",
    height=800
)
fig.update_yaxes(visible=True, showticklabels=False)
fig.show()
fig.write_image(FIGURES_DIR / "time_spans_hourly_before_split.png", width=1200, height=800, scale=2)
# Out:
# <div>                            <div id="2786f117-bc3d-4ef3-88e2-4bad846b4bdd" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2786f117-bc3d-4ef3-88e2-4bad846b4bdd")) {                    Plotly.newPlot(                        "2786f117-bc3d-4ef3-88e2-4bad846b4bdd",                        [{"hovertemplate":"\u003cb\u003eSensor 0\u003c\u002fb\u003e\u003cbr\u003eStart: 2022-12-14T06:00:00.000000000\u003cbr\u003eEnd: 2022-12-15T07:00:00.000000000\u003cbr\u003eRecords: 26","mode":"lines","name":"26 records","x":["2022-12-14T06:00:00.000000000","2022-12-15T07:00:00.000000000"],"y":[0,0],"type":"scatter"},{"hovertemplate":"\u003cb\u003eSensor 1\u003c\u002fb\u003e\u003cbr\u003eStart: 2023-02-23T21:00:00.000000000\u003cbr\u003eEnd: 2023-02-26T19:00:00.000000000\u003cbr\u003eRecords: 71","mode":"lines","name":"71 records","x":["2023-02-23T21:00:00.000000000","2023-02-26T19:00:00.000000000"],"y":[1,1],"type":"scatter"},{"hovertemplate":"\u003cb\u003eSensor 2\u003c\u002fb\u003e\u003cbr\u003eStart: 2022-12-19T09:00:00.000000000\u003cbr\u003eEnd: 2022-12-19T12:00:00.000000000\u003cbr\u003eRecords: 4","mode":"lines","name":"4 records","x":["2022-12-19T09:00:00.000000000","2022-12-19T12:00:00.000000000"],"y":[2,2],"type":"scatter"},{"hovertemplate":"\u003cb\u003eSensor 3\u003c\u002fb\u003e\u003cbr\u003eStart: 2024-02-08T01:00:00.000000000\u003cbr\u003eEnd: 2024-03-15T18:00:00.000000000\u003cbr\u003eRecords: 882","mode":"lines","name":"882 records","x":["2024-02-08T01:00:00.000000000","2024-03-15T18:00:00.000000000"],"y":[3,3],"type":"scatter"},{"hovertemplate":"\u003cb\u003eSensor 4\u003c\u002fb\u003e\u003cbr\u003eStart: 2022-11-16T06:00:00.000000000\u003cbr\u003eEnd: 2022-11-22T05:00:00.000000000\u003cbr\u003eRecords: 144","mode":"lines","name":"144 records","x":["2022-11-16T06:00:00.000000000","2022-11-22T05:00:00.000000000"],"y":[4,4],"type":"scatter"},{"hovertemplate":"\u003cb\u003eSensor 5\u003c\u002fb\u003e\u003cbr\u003eStart: 2022-12-10T07:00:00.000000000\u003cbr\u003eEnd: 2022-12-10T10:00:00.000000000\u003cbr\u003eRecords: 4","mode":"lines","name":"4 records","x":["2022-12-10T07:00:00.000000000","2022-12-10T10:00:00.000000000"],"y":[5,5],"type":"scatter"},{"hovertemplate":"\u003cb\u003eSensor 6\u003c\u002fb\u003e\u003cbr\u003eStart: 2024-03-18T17:00:00.000000000\u003cbr\u003eEnd: 2025-04-22T11:00:00.000000000\u003cbr\u003eRecords: 9595","mode":"lines","name":"9595 records","x":["2024-03-18T17:00:00.000000000","2025-04-22T11:00:00.000000000"],"y":[6,6],"type":"scatter"},{"hovertemplate":"\u003cb\u003eSensor 7\u003c\u002fb\u003e\u003cbr\u003eStart: 2023-06-11T15:00:00.000000000\u003cbr\u003eEnd: 2023-06-14T20:00:00.000000000\u003cbr\u003eRecords: 78","mode":"lines","name":"78 records","x":["2023-06-11T15:00:00.000000000","2023-06-14T20:00:00.000000000"],"y":[7,7],"type":"scatter"},{"hovertemplate":"\u003cb\u003eSensor 8\u003c\u002fb\u003e\u003cbr\u003eStart: 2025-01-03T19:00:00.000000000\u003cbr\u003eEnd: 2025-01-15T08:00:00.000000000\u003cbr\u003eRecords: 278","mode":"lines","name":"278 records","x":["2025-01-03T19:00:00.000000000","2025-01-15T08:00:00.000000000"],"y":[8,8],"type":"scatter"},{"hovertemplate":"\u003cb\u003eSensor 9\u003c\u002fb\u003e\u003cbr\u003eStart: 2022-02-03T17:00:00.000000000\u003cbr\u003eEnd: 2022-02-05T07:00:00.000000000\u003cbr\u003eRecords: 39","mode":"lines","name":"39 records","x":["2022-02-03T17:00:00.000000000","2022-02-05T07:00:00.000000000"],"y":[9,9],"type":"scatter"},{"hovertemplate":"\u003cb\u003eSensor 10\u003c\u002fb\u003e\u003cbr\u003eStart: 2023-07-03T08:00:00.000000000\u003cbr\u003eEnd: 2023-07-06T00:00:00.000000000\u003cbr\u003eRecords: 65","mode":"lines","name":"65 records","x":["2023-07-03T08:00:00.000000000","2023-07-06T00:00:00.000000000"],"y":[10,10],"t ...

# %%
# Daily time spans
df_min_max_dates_daily = df_daily.group_by(["id"]).agg(
    [pl.col("datetime").min().alias("min_date"),
     pl.col("datetime").max().alias("max_date"),
     pl.len().alias("num_records")
     ]
)

fig = go.Figure()
for i, (start, end, sensor_id, num_records) in enumerate(zip(
    df_min_max_dates_daily["min_date"], 
    df_min_max_dates_daily["max_date"],
    df_min_max_dates_daily["id"], 
    df_min_max_dates_daily["num_records"]
)):
    fig.add_trace(go.Scatter(
        x=[start, end], 
        y=[i, i],
        mode='lines',
        name=f"{num_records} records",
        hovertemplate=f"<b>Sensor {i}</b><br>Start: {start}<br>End: {end}<br>Records: {num_records}"
    ))

fig.update_layout(
    title="Daily Data: Time Spans per Sensor (Before Split)",
    title_x=0.5,
    xaxis_title="Date",
    yaxis_title="Sensor Index",
    showlegend=False,
    template="plotly",
    height=800
)
fig.update_yaxes(visible=True, showticklabels=False)
fig.show()
fig.write_image(FIGURES_DIR / "time_spans_daily_before_split.png", width=1200, height=800, scale=2)
# Out:
# <div>                            <div id="665ed0e9-2c94-422b-b7da-c0bf3502e639" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("665ed0e9-2c94-422b-b7da-c0bf3502e639")) {                    Plotly.newPlot(                        "665ed0e9-2c94-422b-b7da-c0bf3502e639",                        [{"hovertemplate":"\u003cb\u003eSensor 0\u003c\u002fb\u003e\u003cbr\u003eStart: 2022-08-24T00:00:00.000000000\u003cbr\u003eEnd: 2023-04-29T00:00:00.000000000\u003cbr\u003eRecords: 249","mode":"lines","name":"249 records","x":["2022-08-24T00:00:00.000000000","2023-04-29T00:00:00.000000000"],"y":[0,0],"type":"scatter"},{"hovertemplate":"\u003cb\u003eSensor 1\u003c\u002fb\u003e\u003cbr\u003eStart: 2022-08-24T00:00:00.000000000\u003cbr\u003eEnd: 2024-01-29T00:00:00.000000000\u003cbr\u003eRecords: 524","mode":"lines","name":"524 records","x":["2022-08-24T00:00:00.000000000","2024-01-29T00:00:00.000000000"],"y":[1,1],"type":"scatter"},{"hovertemplate":"\u003cb\u003eSensor 2\u003c\u002fb\u003e\u003cbr\u003eStart: 2023-06-12T00:00:00.000000000\u003cbr\u003eEnd: 2023-06-22T00:00:00.000000000\u003cbr\u003eRecords: 11","mode":"lines","name":"11 records","x":["2023-06-12T00:00:00.000000000","2023-06-22T00:00:00.000000000"],"y":[2,2],"type":"scatter"},{"hovertemplate":"\u003cb\u003eSensor 3\u003c\u002fb\u003e\u003cbr\u003eStart: 2021-10-23T00:00:00.000000000\u003cbr\u003eEnd: 2022-03-15T00:00:00.000000000\u003cbr\u003eRecords: 144","mode":"lines","name":"144 records","x":["2021-10-23T00:00:00.000000000","2022-03-15T00:00:00.000000000"],"y":[3,3],"type":"scatter"},{"hovertemplate":"\u003cb\u003eSensor 4\u003c\u002fb\u003e\u003cbr\u003eStart: 2021-09-23T00:00:00.000000000\u003cbr\u003eEnd: 2023-01-31T00:00:00.000000000\u003cbr\u003eRecords: 496","mode":"lines","name":"496 records","x":["2021-09-23T00:00:00.000000000","2023-01-31T00:00:00.000000000"],"y":[4,4],"type":"scatter"},{"hovertemplate":"\u003cb\u003eSensor 5\u003c\u002fb\u003e\u003cbr\u003eStart: 2024-06-05T00:00:00.000000000\u003cbr\u003eEnd: 2024-06-27T00:00:00.000000000\u003cbr\u003eRecords: 23","mode":"lines","name":"23 records","x":["2024-06-05T00:00:00.000000000","2024-06-27T00:00:00.000000000"],"y":[5,5],"type":"scatter"},{"hovertemplate":"\u003cb\u003eSensor 6\u003c\u002fb\u003e\u003cbr\u003eStart: 2024-02-09T00:00:00.000000000\u003cbr\u003eEnd: 2025-04-22T00:00:00.000000000\u003cbr\u003eRecords: 439","mode":"lines","name":"439 records","x":["2024-02-09T00:00:00.000000000","2025-04-22T00:00:00.000000000"],"y":[6,6],"type":"scatter"},{"hovertemplate":"\u003cb\u003eSensor 7\u003c\u002fb\u003e\u003cbr\u003eStart: 2023-02-18T00:00:00.000000000\u003cbr\u003eEnd: 2023-04-26T00:00:00.000000000\u003cbr\u003eRecords: 68","mode":"lines","name":"68 records","x":["2023-02-18T00:00:00.000000000","2023-04-26T00:00:00.000000000"],"y":[7,7],"type":"scatter"},{"hovertemplate":"\u003cb\u003eSensor 8\u003c\u002fb\u003e\u003cbr\u003eStart: 2023-05-24T00:00:00.000000000\u003cbr\u003eEnd: 2023-06-03T00:00:00.000000000\u003cbr\u003eRecords: 11","mode":"lines","name":"11 records","x":["2023-05-24T00:00:00.000000000","2023-06-03T00:00:00.000000000"],"y":[8,8],"type":"scatter"},{"hovertemplate":"\u003cb\u003eSensor 9\u003c\u002fb\u003e\u003cbr\u003eStart: 2023-07-12T00:00:00.000000000\u003cbr\u003eEnd: 2024-01-29T00:00:00.000000000\u003cbr\u003eRecords: 202","mode":"lines","name":"202 records","x":["2023-07-12T00:00:00.000000000","2024-01-29T00:00:00.000000000"],"y":[9,9],"type":"scatter"},{"hovertemplate":"\u003cb\u003eSensor 10\u003c\u002fb\u003e\u003cbr\u003eStart: 2022-01-24T00:00:00.000000000\u003cbr\u003eEnd: 2023-09-21T00:00:00.000000000\u003cbr\u003eRecords: 606","mode":"lines","name":"606 records","x":["2022-01-24T00:00:00.000000000","2023-09-21T00:00:00.000000000"],"y":[1 ...

# %% [markdown]
# ## Train/Test/Val Split
#
# Now we'll perform the time-based train/test/val split and see how many sensors remain after filtering out short series.

# %%
# Daily split
config_daily = {
    "dataset": "building",
    "res": "daily",
    "interpolate": 1,
    "lag_in": 7,
    "lag_out": 7,
    "n_in": 7,
    "n_out": 7,
    "energy": "all",
    "train_test_split_method": "time",
    "scale_mode": "individual",
    "scaler": "standard",
    "feature_code": 10
}

print("Loading and splitting daily dataset...")
ds_daily = TrainDatasetBuilding(config_daily)
ds_daily.load_feat_data(interpolate=True)
ds_daily.preprocess()
ds_daily = get_train_test_val_split(ds_daily)

print(f"\nDaily split results:")
n = df_daily['id'].n_unique()
print(f"Original sensors: {n}")
len_discarded_ids = len(ds_daily.discarded_ids)
print(f"Discarded series (too short): {len_discarded_ids}")
len_no_heated_area = len(df_daily.filter(pl.col('heated_area').is_null()).group_by(pl.col('id')).len())
print(f"Discarded series (no building feature): {len_no_heated_area}")
len_remaining_ids = ds_daily.df['id'].n_unique() - len(ds_daily.discarded_ids)
print(f"Discarded series (other reason): {n-(len_discarded_ids+len_no_heated_area+len_remaining_ids)}")
print(f"Remaining series: {len_remaining_ids}")
print(f"Train samples: {len(ds_daily.X_train)}")
print(f"Val samples: {len(ds_daily.X_val)}")
print(f"Test samples: {len(ds_daily.X_test)}")
# Out:
# Loading and splitting daily dataset...
# 2026-04-21 22:43:54.371 | INFO     | src.energy_forecast.dataset:preprocess:606 - Training Features: ['typ_0', 'weekend', 'primary_energy_district heating', 'tmin', 'wspd', 'wdir', 'tsun', 'tavg', 'tmax', 'typ_1', 'prcp', 'pres', 'holiday', 'wpgt', 'hum_avg', 'primary_energy_gas', 'heated_area', 'diff', 'typ_4', 'hum_max', 'hum_min', 'daily_avg', 'typ_2', 'weekday_sin', 'day_of_month_sin', 'weekday_cos', 'day_of_month_cos']
# 2026-04-21 22:43:54.778 | INFO     | src.energy_forecast.utils.train_test_val_split:train_test_split_time_based:85 - Removed 40 series because they were too short
# 2026-04-21 22:43:54.778 | INFO     | src.energy_forecast.utils.train_test_val_split:train_test_split_time_based:87 - Remaining series: 92
# 2026-04-21 22:43:54.897 | INFO     | src.energy_forecast.utils.train_test_val_split:get_train_test_val_split:236 - Train data shape: (43343, 26)
# 2026-04-21 22:43:54.898 | INFO     | src.energy_forecast.utils.train_test_val_split:get_train_test_val_split:237 - Test data shape: (5402, 26)
# 2026-04-21 22:43:54.898 | INFO     | src.energy_forecast.utils.train_test_val_split:get_train_test_val_split:238 - Validation data shape: (5361, 26)
# 2026-04-21 22:43:54.898 | INFO     | src.energy_forecast.utils.train_test_val_split:get_train_test_val_split:239 - Training on 27 features
#
# Daily split results:
# Original sensors: 361
# Discarded series (too short): 40
# Discarded series (no building feature): 221
# Discarded series (other reason): 8
# Remaining series: 92
# Train samples: 43343
# Val samples: 5361
# Test samples: 5402

# %%
len(df_hourly.filter(pl.col("heated_area").is_null()).group_by(pl.col("id")).len())
# Out:
# 833

# %%
# Hourly split
config_hourly = {
    "dataset": "building",
    "res": "hourly",
    "interpolate": 1,
    "lag_in": 72,
    "lag_out": 72,
    "n_in": 72,
    "n_out": 72,
    "energy": "all",
    "train_test_split_method": "time",
    "scale_mode": "individual",
    "scaler": "standard",
    "feature_code": 15
}

print("Loading and splitting hourly dataset...")
ds_hourly = TrainDatasetBuilding(config_hourly)
ds_hourly.load_feat_data(interpolate=True)
ds_hourly.preprocess()
ds_hourly = get_train_test_val_split(ds_hourly)

print(f"\nHourly split results:")
n = df_hourly['id'].n_unique()
print(f"Original sensors: {n}")
len_discarded_ids = len(ds_hourly.discarded_ids)
print(f"Discarded series (too short): {len_discarded_ids}")
len_no_heated_area = len(df_hourly.filter(pl.col('heated_area').is_null()).group_by(pl.col('id')).len())
print(f"Discarded series (no building feature): {len_no_heated_area}")
len_remaining_ids = ds_hourly.df['id'].n_unique() - len(ds_hourly.discarded_ids)
print(f"Discarded series (other reason): {n-(len_discarded_ids+len_no_heated_area+len_remaining_ids)}")
print(f"Remaining series: {len_remaining_ids}")
print(f"Train samples: {len(ds_hourly.X_train)}")
print(f"Val samples: {len(ds_hourly.X_val)}")
print(f"Test samples: {len(ds_hourly.X_test)}")
# Out:
# Loading and splitting hourly dataset...
# 2026-04-21 22:44:02.063 | INFO     | src.energy_forecast.dataset:preprocess:606 - Training Features: ['typ_0', 'weekend', 'primary_energy_district heating', 'dwpt', 'temp', 'wspd', 'rhum', 'wdir', 'tsun', 'typ_1', 'prcp', 'snow', 'pres', 'holiday', 'wpgt', 'primary_energy_gas', 'heated_area', 'coco', 'diff', 'typ_4', 'daily_avg', 'typ_2', 'weekday_sin', 'day_of_month_sin', 'weekday_cos', 'day_of_month_cos']
# 2026-04-21 22:44:02.282 | INFO     | src.energy_forecast.utils.train_test_val_split:train_test_split_time_based:85 - Removed 19 series because they were too short
# 2026-04-21 22:44:02.283 | INFO     | src.energy_forecast.utils.train_test_val_split:train_test_split_time_based:87 - Remaining series: 25
# 2026-04-21 22:44:02.812 | INFO     | src.energy_forecast.utils.train_test_val_split:get_train_test_val_split:236 - Train data shape: (108849, 25)
# 2026-04-21 22:44:02.812 | INFO     | src.energy_forecast.utils.train_test_val_split:get_train_test_val_split:237 - Test data shape: (13603, 25)
# 2026-04-21 22:44:02.812 | INFO     | src.energy_forecast.utils.train_test_val_split:get_train_test_val_split:238 - Validation data shape: (13591, 25)
# 2026-04-21 22:44:02.812 | INFO     | src.energy_forecast.utils.train_test_val_split:get_train_test_val_split:239 - Training on 26 features
#
# Hourly split results:
# Original sensors: 1125
# Discarded series (too short): 19
# Discarded series (no building feature): 833
# Discarded series (other reason): 248
# Remaining series: 25
# Train samples: 108849
# Val samples: 13591
# Test samples: 13603

# %% [markdown]
# ## Time Spans After Split
#
# Visualize the time spans for sensors that remain after filtering and splitting.

# %%
# Get dataframes after split (excluding discarded series)
df_daily_after = ds_daily.df.filter(~pl.col("id").is_in(ds_daily.discarded_ids))

df_min_max_dates_daily_after = df_daily_after.group_by(["id"]).agg(
    [pl.col("datetime").min().alias("min_date"),
     pl.col("datetime").max().alias("max_date"),
     pl.len().alias("num_records")
     ]
)

fig = go.Figure()
for i, (start, end, sensor_id, num_records) in enumerate(zip(
    df_min_max_dates_daily_after["min_date"], 
    df_min_max_dates_daily_after["max_date"],
    df_min_max_dates_daily_after["id"], 
    df_min_max_dates_daily_after["num_records"]
)):
    fig.add_trace(go.Scatter(
        x=[start, end], 
        y=[i, i],
        mode='lines',
        name=f"{num_records} records",
        hovertemplate=f"<b>Sensor {i}</b><br>Start: {start}<br>End: {end}<br>Records: {num_records}"
    ))

fig.update_layout(
    title=f"Daily Data: Time Spans per Sensor (After Split, {len(df_min_max_dates_daily_after)} sensors)",
    title_x=0.5,
    xaxis_title="Date",
    yaxis_title="Sensor Index",
    showlegend=False,
    template="plotly",
    height=800
)
fig.update_yaxes(visible=True, showticklabels=False)
fig.show()
fig.write_image(FIGURES_DIR / "time_spans_daily_after_split.png", width=1200, height=800, scale=2)

print(f"\nSensors before split: {df_daily['id'].n_unique()}")
print(f"Sensors after split: {len(df_min_max_dates_daily_after)}")
# Out:
# <div>                            <div id="9138541b-0c40-49c7-b94f-a0f14638d01d" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9138541b-0c40-49c7-b94f-a0f14638d01d")) {                    Plotly.newPlot(                        "9138541b-0c40-49c7-b94f-a0f14638d01d",                        [{"hovertemplate":"\u003cb\u003eSensor 0\u003c\u002fb\u003e\u003cbr\u003eStart: 2018-08-15 00:00:00\u003cbr\u003eEnd: 2022-03-17 00:00:00\u003cbr\u003eRecords: 1311","mode":"lines","name":"1311 records","x":["2018-08-15T00:00:00","2022-03-17T00:00:00"],"y":[0,0],"type":"scatter"},{"hovertemplate":"\u003cb\u003eSensor 1\u003c\u002fb\u003e\u003cbr\u003eStart: 2021-05-13 00:00:00\u003cbr\u003eEnd: 2022-05-03 00:00:00\u003cbr\u003eRecords: 356","mode":"lines","name":"356 records","x":["2021-05-13T00:00:00","2022-05-03T00:00:00"],"y":[1,1],"type":"scatter"},{"hovertemplate":"\u003cb\u003eSensor 2\u003c\u002fb\u003e\u003cbr\u003eStart: 2019-10-20 00:00:00\u003cbr\u003eEnd: 2020-04-20 00:00:00\u003cbr\u003eRecords: 184","mode":"lines","name":"184 records","x":["2019-10-20T00:00:00","2020-04-20T00:00:00"],"y":[2,2],"type":"scatter"},{"hovertemplate":"\u003cb\u003eSensor 3\u003c\u002fb\u003e\u003cbr\u003eStart: 2019-05-11 00:00:00\u003cbr\u003eEnd: 2020-03-04 00:00:00\u003cbr\u003eRecords: 299","mode":"lines","name":"299 records","x":["2019-05-11T00:00:00","2020-03-04T00:00:00"],"y":[3,3],"type":"scatter"},{"hovertemplate":"\u003cb\u003eSensor 4\u003c\u002fb\u003e\u003cbr\u003eStart: 2020-07-31 00:00:00\u003cbr\u003eEnd: 2022-03-19 00:00:00\u003cbr\u003eRecords: 597","mode":"lines","name":"597 records","x":["2020-07-31T00:00:00","2022-03-19T00:00:00"],"y":[4,4],"type":"scatter"},{"hovertemplate":"\u003cb\u003eSensor 5\u003c\u002fb\u003e\u003cbr\u003eStart: 2020-09-18 00:00:00\u003cbr\u003eEnd: 2022-03-10 00:00:00\u003cbr\u003eRecords: 539","mode":"lines","name":"539 records","x":["2020-09-18T00:00:00","2022-03-10T00:00:00"],"y":[5,5],"type":"scatter"},{"hovertemplate":"\u003cb\u003eSensor 6\u003c\u002fb\u003e\u003cbr\u003eStart: 2018-10-02 00:00:00\u003cbr\u003eEnd: 2019-11-06 00:00:00\u003cbr\u003eRecords: 401","mode":"lines","name":"401 records","x":["2018-10-02T00:00:00","2019-11-06T00:00:00"],"y":[6,6],"type":"scatter"},{"hovertemplate":"\u003cb\u003eSensor 7\u003c\u002fb\u003e\u003cbr\u003eStart: 2021-09-30 00:00:00\u003cbr\u003eEnd: 2023-07-01 00:00:00\u003cbr\u003eRecords: 640","mode":"lines","name":"640 records","x":["2021-09-30T00:00:00","2023-07-01T00:00:00"],"y":[7,7],"type":"scatter"},{"hovertemplate":"\u003cb\u003eSensor 8\u003c\u002fb\u003e\u003cbr\u003eStart: 2018-09-05 00:00:00\u003cbr\u003eEnd: 2019-06-28 00:00:00\u003cbr\u003eRecords: 297","mode":"lines","name":"297 records","x":["2018-09-05T00:00:00","2019-06-28T00:00:00"],"y":[8,8],"type":"scatter"},{"hovertemplate":"\u003cb\u003eSensor 9\u003c\u002fb\u003e\u003cbr\u003eStart: 2018-08-15 00:00:00\u003cbr\u003eEnd: 2022-03-17 00:00:00\u003cbr\u003eRecords: 1311","mode":"lines","name":"1311 records","x":["2018-08-15T00:00:00","2022-03-17T00:00:00"],"y":[9,9],"type":"scatter"},{"hovertemplate":"\u003cb\u003eSensor 10\u003c\u002fb\u003e\u003cbr\u003eStart: 2022-10-26 00:00:00\u003cbr\u003eEnd: 2023-09-07 00:00:00\u003cbr\u003eRecords: 317","mode":"lines","name":"317 records","x":["2022-10-26T00:00:00","2023-09-07T00:00:00"],"y":[10,10],"type":"scatter"},{"hovertemplate":"\u003cb\u003eSensor 11\u003c\u002fb\u003e\u003cbr\u003eStart: 2021-09-30 00:00:00\u003cbr\u003eEnd: 2023-01-25 00:00:00\u003cbr\u003eRecords: 483","mode":"lines","name":"483 records","x":["2021-09-30T00:00:00","2023-01-25T00:00:00"],"y":[11,11],"type":"scatter"},{"hovertemplate":"\u003cb\u003eSensor 12\u003c\u002fb\u003e\u003cbr\u003eStart: 2021-04-07 00:00:00\u003cbr\u003eEnd: 2021- ...
# Sensors before split: 361
# Sensors after split: 92

# %%
# Get dataframes after split (excluding discarded series)
df_hourly_after = ds_hourly.df.filter(~pl.col("id").is_in(ds_hourly.discarded_ids))

df_min_max_dates_hourly_after = df_hourly_after.group_by(["id"]).agg(
    [pl.col("datetime").min().alias("min_date"),
     pl.col("datetime").max().alias("max_date"),
     pl.len().alias("num_records")
     ]
)

fig = go.Figure()
for i, (start, end, sensor_id, num_records) in enumerate(zip(
    df_min_max_dates_hourly_after["min_date"], 
    df_min_max_dates_hourly_after["max_date"],
    df_min_max_dates_hourly_after["id"], 
    df_min_max_dates_hourly_after["num_records"]
)):
    fig.add_trace(go.Scatter(
        x=[start, end], 
        y=[i, i],
        mode='lines',
        name=f"{num_records} records",
        hovertemplate=f"<b>Sensor {i}</b><br>Start: {start}<br>End: {end}<br>Records: {num_records}"
    ))

fig.update_layout(
    title=f"Hourly Data: Time Spans per Sensor (After Split, {len(df_min_max_dates_hourly_after)} sensors)",
    title_x=0.5,
    xaxis_title="Date",
    yaxis_title="Sensor Index",
    showlegend=False,
    template="plotly",
    height=800
)
fig.update_yaxes(visible=True, showticklabels=False)
fig.show()
fig.write_image(FIGURES_DIR / "time_spans_hourly_after_split.png", width=1200, height=800, scale=2)

print(f"\nSensors before split: {df_hourly['id'].n_unique()}")
print(f"Sensors after split: {len(df_min_max_dates_hourly_after)}")
# Out:
# <div>                            <div id="22f230ca-ee48-498f-b2b1-209d1a617772" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("22f230ca-ee48-498f-b2b1-209d1a617772")) {                    Plotly.newPlot(                        "22f230ca-ee48-498f-b2b1-209d1a617772",                        [{"hovertemplate":"\u003cb\u003eSensor 0\u003c\u002fb\u003e\u003cbr\u003eStart: 2021-10-01 04:00:00\u003cbr\u003eEnd: 2021-12-30 03:00:00\u003cbr\u003eRecords: 2160","mode":"lines","name":"2160 records","x":["2021-10-01T04:00:00","2021-12-30T03:00:00"],"y":[0,0],"type":"scatter"},{"hovertemplate":"\u003cb\u003eSensor 1\u003c\u002fb\u003e\u003cbr\u003eStart: 2022-01-06 09:00:00\u003cbr\u003eEnd: 2023-09-15 14:00:00\u003cbr\u003eRecords: 14804","mode":"lines","name":"14804 records","x":["2022-01-06T09:00:00","2023-09-15T14:00:00"],"y":[1,1],"type":"scatter"},{"hovertemplate":"\u003cb\u003eSensor 2\u003c\u002fb\u003e\u003cbr\u003eStart: 2021-10-07 14:00:00\u003cbr\u003eEnd: 2021-12-30 03:00:00\u003cbr\u003eRecords: 2006","mode":"lines","name":"2006 records","x":["2021-10-07T14:00:00","2021-12-30T03:00:00"],"y":[2,2],"type":"scatter"},{"hovertemplate":"\u003cb\u003eSensor 3\u003c\u002fb\u003e\u003cbr\u003eStart: 2022-01-27 13:00:00\u003cbr\u003eEnd: 2023-09-18 09:00:00\u003cbr\u003eRecords: 14362","mode":"lines","name":"14362 records","x":["2022-01-27T13:00:00","2023-09-18T09:00:00"],"y":[3,3],"type":"scatter"},{"hovertemplate":"\u003cb\u003eSensor 4\u003c\u002fb\u003e\u003cbr\u003eStart: 2021-10-07 10:00:00\u003cbr\u003eEnd: 2021-12-30 03:00:00\u003cbr\u003eRecords: 2001","mode":"lines","name":"2001 records","x":["2021-10-07T10:00:00","2021-12-30T03:00:00"],"y":[4,4],"type":"scatter"},{"hovertemplate":"\u003cb\u003eSensor 5\u003c\u002fb\u003e\u003cbr\u003eStart: 2022-09-03 22:00:00\u003cbr\u003eEnd: 2023-06-12 16:00:00\u003cbr\u003eRecords: 6762","mode":"lines","name":"6762 records","x":["2022-09-03T22:00:00","2023-06-12T16:00:00"],"y":[5,5],"type":"scatter"},{"hovertemplate":"\u003cb\u003eSensor 6\u003c\u002fb\u003e\u003cbr\u003eStart: 2022-04-10 17:00:00\u003cbr\u003eEnd: 2022-11-01 18:00:00\u003cbr\u003eRecords: 4890","mode":"lines","name":"4890 records","x":["2022-04-10T17:00:00","2022-11-01T18:00:00"],"y":[6,6],"type":"scatter"},{"hovertemplate":"\u003cb\u003eSensor 7\u003c\u002fb\u003e\u003cbr\u003eStart: 2022-02-26 22:00:00\u003cbr\u003eEnd: 2023-01-28 10:00:00\u003cbr\u003eRecords: 7926","mode":"lines","name":"7926 records","x":["2022-02-26T22:00:00","2023-01-28T10:00:00"],"y":[7,7],"type":"scatter"},{"hovertemplate":"\u003cb\u003eSensor 8\u003c\u002fb\u003e\u003cbr\u003eStart: 2023-06-22 13:00:00\u003cbr\u003eEnd: 2023-09-15 16:00:00\u003cbr\u003eRecords: 2042","mode":"lines","name":"2042 records","x":["2023-06-22T13:00:00","2023-09-15T16:00:00"],"y":[8,8],"type":"scatter"},{"hovertemplate":"\u003cb\u003eSensor 9\u003c\u002fb\u003e\u003cbr\u003eStart: 2023-04-19 12:00:00\u003cbr\u003eEnd: 2023-09-09 15:00:00\u003cbr\u003eRecords: 3414","mode":"lines","name":"3414 records","x":["2023-04-19T12:00:00","2023-09-09T15:00:00"],"y":[9,9],"type":"scatter"},{"hovertemplate":"\u003cb\u003eSensor 10\u003c\u002fb\u003e\u003cbr\u003eStart: 2022-04-07 13:00:00\u003cbr\u003eEnd: 2022-10-02 09:00:00\u003cbr\u003eRecords: 4237","mode":"lines","name":"4237 records","x":["2022-04-07T13:00:00","2022-10-02T09:00:00"],"y":[10,10],"type":"scatter"},{"hovertemplate":"\u003cb\u003eSensor 11\u003c\u002fb\u003e\u003cbr\u003eStart: 2022-01-06 09:00:00\u003cbr\u003eEnd: 2023-09-18 11:00:00\u003cbr\u003eRecords: 14872","mode":"lines","name":"14872 records","x":["2022-01-06T09:00:00","2023-09-18T11:00:00"],"y":[11,11],"type":"scatter"},{"hovertemplate":"\u003cb\u003eSensor 12\u003c\u002fb\u003e\u003cbr\u003eStart: 2022-11-15 00:00: ...
# Sensors before split: 1125
# Sensors after split: 25

# %% [markdown]
# ## Outlier Detection Example
#
# Demonstrate outlier detection using IQR method on a sample sensor.

# %%
# Create a raw daily dataset to show outliers
ds_raw = Dataset(res="daily")
ds_raw.create()

# Pick a sensor with known outliers
sensor_id = SENSOR_IDS["outlier_example_daily"]
df_sensor = ds_raw.df.filter(pl.col("id") == sensor_id)
df_sensor = df_sensor.select(["id", "datetime", "diff"])

print(f"Records: {len(df_sensor)}")
print(f"Date range: {df_sensor['datetime'].min()} to {df_sensor['datetime'].max()}")
print(f"\nDiff statistics:")
print(df_sensor['diff'].describe())
# Out:
# 2026-04-21 22:44:04.035 | INFO     | src.energy_forecast.dataset:create:50 - Creating daily dataset
# 2026-04-21 22:44:04.059 | INFO     | src.energy_forecast.dataset:create:55 - Number of rows: 110005
# 2026-04-21 22:44:04.069 | INFO     | src.energy_forecast.dataset:create:57 - Number of sensors: 142
# Records: 902
# Date range: 2022-08-24T00:00:00.000000 to 2025-04-22T00:00:00.000000
#
# Diff statistics:
# shape: (9, 2)
# ┌────────────┬────────────┐
# │ statistic  ┆ value      │
# │ ---        ┆ ---        │
# │ str        ┆ f64        │
# ╞════════════╪════════════╡
# │ count      ┆ 902.0      │
# │ null_count ┆ 0.0        │
# │ mean       ┆ 599.484479 │
# │ std        ┆ 406.368221 │
# │ min        ┆ 0.0        │
# │ 25%        ┆ 495.0      │
# │ 50%        ┆ 570.0      │
# │ 75%        ┆ 635.0      │
# │ max        ┆ 6874.0     │
# └────────────┴────────────┘

# %%
# Plot raw data
fig = px.scatter(df_sensor, x="datetime", y="diff", title="Example Sensor: Raw Data")
fig.update_layout(template="plotly")
fig.show()
fig.write_image(FIGURES_DIR / "outlier_raw_data.png", width=1200, height=600, scale=2)
# Out:
# <div>                            <div id="133dbcd6-46a4-4862-b386-2f28c7f67409" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("133dbcd6-46a4-4862-b386-2f28c7f67409")) {                    Plotly.newPlot(                        "133dbcd6-46a4-4862-b386-2f28c7f67409",                        [{"hovertemplate":"datetime=%{x}\u003cbr\u003ediff=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":["2022-08-24T00:00:00.000000","2022-08-25T00:00:00.000000","2022-08-26T00:00:00.000000","2022-08-27T00:00:00.000000","2022-08-28T00:00:00.000000","2022-08-29T00:00:00.000000","2022-08-30T00:00:00.000000","2022-08-31T00:00:00.000000","2022-09-01T00:00:00.000000","2022-09-02T00:00:00.000000","2022-09-03T00:00:00.000000","2022-09-04T00:00:00.000000","2022-09-05T00:00:00.000000","2022-09-06T00:00:00.000000","2022-09-07T00:00:00.000000","2022-09-08T00:00:00.000000","2022-09-09T00:00:00.000000","2022-09-10T00:00:00.000000","2022-09-11T00:00:00.000000","2022-09-12T00:00:00.000000","2022-09-13T00:00:00.000000","2022-09-14T00:00:00.000000","2022-09-15T00:00:00.000000","2022-09-16T00:00:00.000000","2022-09-17T00:00:00.000000","2022-09-18T00:00:00.000000","2022-09-19T00:00:00.000000","2022-09-20T00:00:00.000000","2022-09-21T00:00:00.000000","2022-09-22T00:00:00.000000","2022-09-23T00:00:00.000000","2022-09-24T00:00:00.000000","2022-09-25T00:00:00.000000","2022-09-26T00:00:00.000000","2022-09-27T00:00:00.000000","2022-09-28T00:00:00.000000","2022-09-29T00:00:00.000000","2022-09-30T00:00:00.000000","2022-10-01T00:00:00.000000","2022-10-02T00:00:00.000000","2022-10-03T00:00:00.000000","2022-10-04T00:00:00.000000","2022-10-05T00:00:00.000000","2022-10-06T00:00:00.000000","2022-10-07T00:00:00.000000","2022-10-08T00:00:00.000000","2022-10-09T00:00:00.000000","2022-10-10T00:00:00.000000","2022-10-11T00:00:00.000000","2022-10-12T00:00:00.000000","2022-10-13T00:00:00.000000","2022-10-14T00:00:00.000000","2022-10-15T00:00:00.000000","2022-10-16T00:00:00.000000","2022-10-17T00:00:00.000000","2022-10-18T00:00:00.000000","2022-10-19T00:00:00.000000","2022-10-20T00:00:00.000000","2022-10-21T00:00:00.000000","2022-10-22T00:00:00.000000","2022-10-23T00:00:00.000000","2022-10-24T00:00:00.000000","2022-10-25T00:00:00.000000","2022-10-26T00:00:00.000000","2022-10-27T00:00:00.000000","2022-10-28T00:00:00.000000","2022-10-29T00:00:00.000000","2022-10-30T00:00:00.000000","2022-10-31T00:00:00.000000","2022-11-01T00:00:00.000000","2022-11-02T00:00:00.000000","2022-11-03T00:00:00.000000","2022-11-04T00:00:00.000000","2022-11-05T00:00:00.000000","2022-11-06T00:00:00.000000","2022-11-07T00:00:00.000000","2022-11-08T00:00:00.000000","2022-11-09T00:00:00.000000","2022-11-10T00:00:00.000000","2022-11-11T00:00:00.000000","2022-11-12T00:00:00.000000","2022-11-13T00:00:00.000000","2022-11-14T00:00:00.000000","2022-11-15T00:00:00.000000","2022-11-16T00:00:00.000000","2022-11-17T00:00:00.000000","2022-11-18T00:00:00.000000","2022-11-19T00:00:00.000000","2022-11-20T00:00:00.000000","2022-11-21T00:00:00.000000","2022-11-22T00:00:00.000000","2022-11-23T00:00:00.000000","2022-11-24T00:00:00.000000","2022-11-25T00:00:00.000000","2022-11-26T00:00:00.000000","2022-11-27T00:00:00.000000","2022-11-28T00:00:00.000000","2022-11-29T00:00:00.000000","2022-11-30T00:00:00.000000","2022-12-03T00:00:00.000000","2022-12-04T00:00:00.000000","2022-12-05T00:00:00.000000","2022-12-06T00:00:00.000000","2022-12-07T00:00:00.000000","2022-12-08T00:00:00.000000","2022-12-09T00:00:00.000000","2022-12-10T00:00:00.000000","2022-12-11T00:00:00.000000","2022-12-12T00:00:00.000000","2022-12-13T00:00:00.000000","2022-12-14T00:00:00.000000","2022-12-15T00:00:00. ...

# %%
# Apply IQR outlier detection
column = "diff"
q25 = df_sensor[column].quantile(0.25)
q75 = df_sensor[column].quantile(0.75)
iqr = q75 - q25

upper_bound = q75 + 1.5 * iqr
lower_bound = q25 - 1.5 * iqr

print(f"Q25: {q25:.2f}")
print(f"Q75: {q75:.2f}")
print(f"IQR: {iqr:.2f}")
print(f"Lower bound: {lower_bound:.2f}")
print(f"Upper bound: {upper_bound:.2f}")

# Mark outliers
df_with_outliers = df_sensor.with_columns(
    ((pl.col(column) > upper_bound) | (pl.col(column) < lower_bound)).alias("outlier")
)

num_outliers = df_with_outliers.filter(pl.col("outlier")).height
print(f"\nOutliers detected: {num_outliers} ({num_outliers/len(df_sensor)*100:.1f}%)")

# Plot with outliers marked
fig = px.scatter(df_with_outliers, x="datetime", y="diff", color="outlier",
                 title="Example Sensor: Outlier Detection (IQR Method)")
fig.update_layout(template="plotly")
fig.show()
fig.write_image(FIGURES_DIR / "outlier_detection_iqr.png", width=1200, height=600, scale=2)
# Out:
# Q25: 495.00
# Q75: 635.00
# IQR: 140.00
# Lower bound: 285.00
# Upper bound: 845.00
#
# Outliers detected: 94 (10.4%)
# <div>                            <div id="a19a2119-8014-42e3-8233-4a325bedff7a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a19a2119-8014-42e3-8233-4a325bedff7a")) {                    Plotly.newPlot(                        "a19a2119-8014-42e3-8233-4a325bedff7a",                        [{"hovertemplate":"outlier=False\u003cbr\u003edatetime=%{x}\u003cbr\u003ediff=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"False","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"False","orientation":"v","showlegend":true,"x":["2022-08-24T00:00:00.000000","2022-08-25T00:00:00.000000","2022-08-26T00:00:00.000000","2022-08-27T00:00:00.000000","2022-08-28T00:00:00.000000","2022-08-29T00:00:00.000000","2022-08-30T00:00:00.000000","2022-08-31T00:00:00.000000","2022-09-01T00:00:00.000000","2022-09-02T00:00:00.000000","2022-09-03T00:00:00.000000","2022-09-04T00:00:00.000000","2022-09-05T00:00:00.000000","2022-09-06T00:00:00.000000","2022-09-07T00:00:00.000000","2022-09-08T00:00:00.000000","2022-09-09T00:00:00.000000","2022-09-10T00:00:00.000000","2022-09-11T00:00:00.000000","2022-09-12T00:00:00.000000","2022-09-13T00:00:00.000000","2022-09-14T00:00:00.000000","2022-09-15T00:00:00.000000","2022-09-16T00:00:00.000000","2022-09-17T00:00:00.000000","2022-09-18T00:00:00.000000","2022-09-19T00:00:00.000000","2022-09-20T00:00:00.000000","2022-09-21T00:00:00.000000","2022-09-22T00:00:00.000000","2022-09-23T00:00:00.000000","2022-09-24T00:00:00.000000","2022-09-25T00:00:00.000000","2022-09-26T00:00:00.000000","2022-09-27T00:00:00.000000","2022-09-28T00:00:00.000000","2022-09-29T00:00:00.000000","2022-09-30T00:00:00.000000","2022-10-01T00:00:00.000000","2022-10-02T00:00:00.000000","2022-10-03T00:00:00.000000","2022-10-04T00:00:00.000000","2022-10-05T00:00:00.000000","2022-10-06T00:00:00.000000","2022-10-07T00:00:00.000000","2022-10-08T00:00:00.000000","2022-10-09T00:00:00.000000","2022-10-10T00:00:00.000000","2022-10-11T00:00:00.000000","2022-10-12T00:00:00.000000","2022-10-13T00:00:00.000000","2022-10-14T00:00:00.000000","2022-10-15T00:00:00.000000","2022-10-16T00:00:00.000000","2022-10-17T00:00:00.000000","2022-10-18T00:00:00.000000","2022-10-19T00:00:00.000000","2022-10-20T00:00:00.000000","2022-10-21T00:00:00.000000","2022-10-22T00:00:00.000000","2022-10-23T00:00:00.000000","2022-10-24T00:00:00.000000","2022-10-25T00:00:00.000000","2022-10-26T00:00:00.000000","2022-10-27T00:00:00.000000","2022-10-28T00:00:00.000000","2022-10-29T00:00:00.000000","2022-10-30T00:00:00.000000","2022-10-31T00:00:00.000000","2022-11-01T00:00:00.000000","2022-11-02T00:00:00.000000","2022-11-03T00:00:00.000000","2022-11-04T00:00:00.000000","2022-11-05T00:00:00.000000","2022-11-06T00:00:00.000000","2022-11-07T00:00:00.000000","2022-11-08T00:00:00.000000","2022-11-09T00:00:00.000000","2022-11-10T00:00:00.000000","2022-11-11T00:00:00.000000","2022-11-12T00:00:00.000000","2022-11-13T00:00:00.000000","2022-11-14T00:00:00.000000","2022-11-15T00:00:00.000000","2022-11-16T00:00:00.000000","2022-11-17T00:00:00.000000","2022-11-18T00:00:00.000000","2022-11-19T00:00:00.000000","2022-11-20T00:00:00.000000","2022-11-21T00:00:00.000000","2022-11-22T00:00:00.000000","2022-11-23T00:00:00.000000","2022-11-24T00:00:00.000000","2022-11-25T00:00:00.000000","2022-11-26T00:00:00.000000","2022-11-27T00:00:00.000000","2022-11-28T00:00:00.000000","2022-11-29T00:00:00.000000","2022-11-30T00:00:00.000000","2022-12-04T00:00:00.000000","2022-12-05T00:00:00.000000","2022-12-06T00:00:00.000000","2022-12-07T00:00:00.000000","2022-12-08T00:00:00.000000","2022-12-09T00:00:00.000000","2022-12-10T00:00:00.000000","2022-12-11T00:00:00.000000","2022-12-12T00:00:00.000000","2022-12-13T00:00:00.000000","2022-12-14T00:00:00.000000","2022-12-15T00 ...

# %% [markdown]
# ## Interpolation Process: Before and After
#
# Demonstrate the data cleaning and interpolation process using the `InterpolatedDataset.clean()` method.

# %%
# Load raw daily data (before interpolation)
print("Creating raw daily dataset (before interpolation)...")
ds_daily_raw = Dataset(res="daily")
ds_daily_raw.create()

print(f"\nRaw daily dataset:")
print(f"Total records: {len(ds_daily_raw.df)}")
print(f"Unique sensors: {ds_daily_raw.df['id'].n_unique()}")
print(f"Date range: {ds_daily_raw.df['datetime'].min()} to {ds_daily_raw.df['datetime'].max()}")
# Out:
# Creating raw daily dataset (before interpolation)...
# 2026-04-21 22:44:04.742 | INFO     | src.energy_forecast.dataset:create:50 - Creating daily dataset
# 2026-04-21 22:44:04.759 | INFO     | src.energy_forecast.dataset:create:55 - Number of rows: 110005
# 2026-04-21 22:44:04.769 | INFO     | src.energy_forecast.dataset:create:57 - Number of sensors: 142
#
# Raw daily dataset:
# Total records: 110005
# Unique sensors: 142
# Date range: 2017-03-14T00:00:00.000000 to 2025-04-22T00:00:00.000000

# %%
# Apply cleaning (removes outliers, negative values, etc.)
print("Cleaning raw daily data (removes outliers, negatives, flat lines, connection errors)...")
ds_daily_raw.clean(plot=False)

print(f"\nAfter cleaning:")
print(f"Total records: {len(ds_daily_raw.df)}")
print(f"Unique sensors: {ds_daily_raw.df['id'].n_unique()}")
print(f"Records removed: {len(ds_daily_raw.df) - len(ds_daily_raw.df)}")
# Out:
# Cleaning raw daily data (removes outliers, negatives, flat lines, connection errors)...
# 2026-04-21 22:44:04.814 | INFO     | src.energy_forecast.dataset:clean:65 - Cleaning daily dataset
# 2026-04-21 22:44:04.814 | INFO     | src.energy_forecast.dataset:clean:67 - Number of rows: 110005
# 2026-04-21 22:44:04.814 | INFO     | src.energy_forecast.dataset:clean:69 - Removing negative diff values
# 2026-04-21 22:44:04.823 | INFO     | src.energy_forecast.dataset:clean:71 - Number of rows after removing negative values: 109958
# 2026-04-21 22:44:04.824 | INFO     | src.energy_forecast.dataset:clean:73 - Filter connection error values
# 2026-04-21 22:44:06.339 | INFO     | src.energy_forecast.dataset:clean:76 - Number of rows after removing connection error values: 108757
# 2026-04-21 22:44:06.340 | INFO     | src.energy_forecast.dataset:clean:78 - Filtering outliers
# 2026-04-21 22:44:06.369 | INFO     | src.energy_forecast.dataset:clean:80 - Number of rows after filtering outliers: 108067
# 2026-04-21 22:44:06.369 | INFO     | src.energy_forecast.dataset:clean:82 - Filtering flat lines
# 2026-04-21 22:44:07.894 | INFO     | src.energy_forecast.dataset:clean:85 - Number of rows after filtering flat lines: 101868
# 2026-04-21 22:44:08.254 | INFO     | src.energy_forecast.utils.util:get_missing_dates:110 - Wrote information about missing dates to /home/marja/PycharmProjects/energy-forecast-wahl/reports/missing_dates_D.csv
# 2026-04-21 22:44:08.257 | INFO     | src.energy_forecast.dataset:clean:89 - Number of sensors after cleaning data: 141
# 2026-04-21 22:44:08.257 | SUCCESS  | src.energy_forecast.dataset:clean:90 - Number of rows after cleaning data: 101868
#
# After cleaning:
# Total records: 101868
# Unique sensors: 141
# Records removed: 0

# %%
# Now create interpolated dataset
print("Creating interpolated daily dataset...")
ds_daily_interpolated = InterpolatedDataset(res="daily")
ds_daily_interpolated.create()
ds_daily_interpolated.clean(plot=False)

print(f"\nAfter interpolation:")
print(f"Total records: {len(ds_daily_interpolated.df)}")
print(f"Unique sensors/series: {ds_daily_interpolated.df['id'].n_unique()}")
print(f"Records added: {len(ds_daily_interpolated.df) - len(ds_daily_raw.df)}")
# Out:
# Creating interpolated daily dataset...
# 2026-04-21 22:44:08.361 | INFO     | src.energy_forecast.dataset:create:50 - Creating daily dataset
# 2026-04-21 22:44:08.374 | INFO     | src.energy_forecast.dataset:create:55 - Number of rows: 110005
# 2026-04-21 22:44:08.385 | INFO     | src.energy_forecast.dataset:create:57 - Number of sensors: 142
# 2026-04-21 22:44:08.385 | INFO     | src.energy_forecast.dataset:clean:65 - Cleaning daily dataset
# 2026-04-21 22:44:08.386 | INFO     | src.energy_forecast.dataset:clean:67 - Number of rows: 110005
# 2026-04-21 22:44:08.386 | INFO     | src.energy_forecast.dataset:clean:69 - Removing negative diff values
# 2026-04-21 22:44:08.390 | INFO     | src.energy_forecast.dataset:clean:71 - Number of rows after removing negative values: 109958
# 2026-04-21 22:44:08.390 | INFO     | src.energy_forecast.dataset:clean:73 - Filter connection error values
# 2026-04-21 22:44:10.399 | INFO     | src.energy_forecast.dataset:clean:76 - Number of rows after removing connection error values: 108757
# 2026-04-21 22:44:10.400 | INFO     | src.energy_forecast.dataset:clean:78 - Filtering outliers
# 2026-04-21 22:44:10.459 | INFO     | src.energy_forecast.dataset:clean:80 - Number of rows after filtering outliers: 108067
# 2026-04-21 22:44:10.459 | INFO     | src.energy_forecast.dataset:clean:82 - Filtering flat lines
# 2026-04-21 22:44:11.958 | INFO     | src.energy_forecast.dataset:clean:85 - Number of rows after filtering flat lines: 101868
# 2026-04-21 22:44:12.277 | INFO     | src.energy_forecast.utils.util:get_missing_dates:110 - Wrote information about missing dates to /home/marja/PycharmProjects/energy-forecast-wahl/reports/missing_dates_D.csv
# 2026-04-21 22:44:12.279 | INFO     | src.energy_forecast.dataset:clean:89 - Number of sensors after cleaning data: 141
# 2026-04-21 22:44:12.279 | SUCCESS  | src.energy_forecast.dataset:clean:90 - Number of rows after cleaning data: 101868
# 2026-04-21 22:44:12.280 | INFO     | src.energy_forecast.dataset:clean:238 - Split series with long series of missing values
# 2026-04-21 22:44:15.492 | INFO     | src.energy_forecast.dataset:clean:243 - Interpolating values
# 2026-04-21 22:44:20.618 | INFO     | src.energy_forecast.dataset:clean:246 - Remove negative consumption values
# 2026-04-21 22:44:20.624 | INFO     | src.energy_forecast.dataset:clean:249 - Split series with long series of missing values
# 2026-04-21 22:44:23.959 | INFO     | src.energy_forecast.dataset:clean:252 - Number of rows after interpolating: 104223
# 2026-04-21 22:44:23.970 | INFO     | src.energy_forecast.dataset:clean:260 - Saved series info to /home/marja/PycharmProjects/energy-forecast-wahl/reports/dataset_interpolate_daily_7_series_info.csv
# 2026-04-21 22:44:23.970 | INFO     | src.energy_forecast.dataset:clean:261 - Number of series after splitting: 364
#
# After interpolation:
# Total records: 104223
# Unique sensors/series: 362
# Records added: 2355

# %% [markdown]
# ### Visualize Interpolation: Before and After
#
# Compare a sensor's data before and after interpolation.

# %%
# Select a sensor that exists in both datasets
common_sensors = set(ds_daily_raw.df['id'].unique()) & set(ds_daily_interpolated.df['id'].unique())
sample_sensor = list(common_sensors)[0]

# Get data before and after interpolation
df_before = ds_daily_raw.df.filter(pl.col("id") == sample_sensor).sort("datetime")
df_after = ds_daily_interpolated.df.filter(pl.col("id") == sample_sensor).sort("datetime")

print(f"Before interpolation:")
print(f"  Records: {len(df_before)}")
print(f"  Date range: {df_before['datetime'].min()} to {df_before['datetime'].max()}")

print(f"\nAfter interpolation:")
print(f"  Records: {len(df_after)}")
print(f"  Date range: {df_after['datetime'].min()} to {df_after['datetime'].max()}")
print(f"\nRecords added by interpolation: {len(df_after) - len(df_before)}")
# Out:
# Before interpolation:
#   Records: 207
#   Date range: 2021-08-18 00:00:00 to 2022-03-16 00:00:00
#
# After interpolation:
#   Records: 211
#   Date range: 2021-08-18 00:00:00 to 2022-03-16 00:00:00
#
# Records added by interpolation: 4

# %%
# Plot before and after side by side
from plotly.subplots import make_subplots

fig = make_subplots(
    rows=2, cols=1,
    subplot_titles=("Before Interpolation", "After Interpolation"),
    vertical_spacing=0.12
)

# Before interpolation
fig.add_trace(
    go.Scatter(x=df_before['datetime'], y=df_before['diff'], 
               mode='lines+markers', name='Before',
               line=dict(color='blue')),
    row=1, col=1
)

# After interpolation
fig.add_trace(
    go.Scatter(x=df_after['datetime'], y=df_after['diff'], 
               mode='lines+markers', name='After',
               line=dict(color='green')),
    row=2, col=1
)

fig.update_xaxes(title_text="Date", row=2, col=1)
fig.update_yaxes(title_text="Consumption (diff)", row=1, col=1)
fig.update_yaxes(title_text="Consumption (diff)", row=2, col=1)

fig.update_layout(
    title_text="Daily Data Interpolation: Example Sensor",
    template="plotly",
    height=800,
    showlegend=True
)

fig.show()
fig.write_image(FIGURES_DIR / "interpolation_daily_before_after.png", width=1200, height=800, scale=2)
# Out:
# <div>                            <div id="05d94e41-70ab-44a8-b50b-eebab7bfad6a" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("05d94e41-70ab-44a8-b50b-eebab7bfad6a")) {                    Plotly.newPlot(                        "05d94e41-70ab-44a8-b50b-eebab7bfad6a",                        [{"line":{"color":"blue"},"mode":"lines+markers","name":"Before","x":["2021-08-18T00:00:00","2021-08-19T00:00:00","2021-08-20T00:00:00","2021-08-21T00:00:00","2021-08-22T00:00:00","2021-08-23T00:00:00","2021-08-24T00:00:00","2021-08-25T00:00:00","2021-08-26T00:00:00","2021-08-27T00:00:00","2021-08-28T00:00:00","2021-08-29T00:00:00","2021-08-30T00:00:00","2021-08-31T00:00:00","2021-09-01T00:00:00","2021-09-02T00:00:00","2021-09-03T00:00:00","2021-09-04T00:00:00","2021-09-05T00:00:00","2021-09-06T00:00:00","2021-09-07T00:00:00","2021-09-08T00:00:00","2021-09-09T00:00:00","2021-09-10T00:00:00","2021-09-11T00:00:00","2021-09-12T00:00:00","2021-09-13T00:00:00","2021-09-14T00:00:00","2021-09-15T00:00:00","2021-09-16T00:00:00","2021-09-17T00:00:00","2021-09-18T00:00:00","2021-09-19T00:00:00","2021-09-20T00:00:00","2021-09-21T00:00:00","2021-09-22T00:00:00","2021-09-23T00:00:00","2021-09-24T00:00:00","2021-09-25T00:00:00","2021-09-26T00:00:00","2021-09-27T00:00:00","2021-09-28T00:00:00","2021-09-29T00:00:00","2021-09-30T00:00:00","2021-10-01T00:00:00","2021-10-02T00:00:00","2021-10-03T00:00:00","2021-10-04T00:00:00","2021-10-05T00:00:00","2021-10-06T00:00:00","2021-10-07T00:00:00","2021-10-08T00:00:00","2021-10-09T00:00:00","2021-10-10T00:00:00","2021-10-11T00:00:00","2021-10-12T00:00:00","2021-10-13T00:00:00","2021-10-14T00:00:00","2021-10-15T00:00:00","2021-10-16T00:00:00","2021-10-17T00:00:00","2021-10-18T00:00:00","2021-10-19T00:00:00","2021-10-20T00:00:00","2021-10-21T00:00:00","2021-10-22T00:00:00","2021-10-23T00:00:00","2021-10-24T00:00:00","2021-10-25T00:00:00","2021-10-26T00:00:00","2021-10-27T00:00:00","2021-10-28T00:00:00","2021-10-29T00:00:00","2021-10-30T00:00:00","2021-10-31T00:00:00","2021-11-01T00:00:00","2021-11-02T00:00:00","2021-11-03T00:00:00","2021-11-04T00:00:00","2021-11-05T00:00:00","2021-11-06T00:00:00","2021-11-07T00:00:00","2021-11-08T00:00:00","2021-11-09T00:00:00","2021-11-10T00:00:00","2021-11-11T00:00:00","2021-11-12T00:00:00","2021-11-13T00:00:00","2021-11-14T00:00:00","2021-11-15T00:00:00","2021-11-16T00:00:00","2021-11-17T00:00:00","2021-11-18T00:00:00","2021-11-19T00:00:00","2021-11-20T00:00:00","2021-11-21T00:00:00","2021-11-22T00:00:00","2021-11-23T00:00:00","2021-11-24T00:00:00","2021-11-25T00:00:00","2021-11-26T00:00:00","2021-11-27T00:00:00","2021-11-28T00:00:00","2021-11-29T00:00:00","2021-11-30T00:00:00","2021-12-01T00:00:00","2021-12-02T00:00:00","2021-12-03T00:00:00","2021-12-04T00:00:00","2021-12-05T00:00:00","2021-12-06T00:00:00","2021-12-07T00:00:00","2021-12-08T00:00:00","2021-12-09T00:00:00","2021-12-10T00:00:00","2021-12-11T00:00:00","2021-12-12T00:00:00","2021-12-13T00:00:00","2021-12-14T00:00:00","2021-12-15T00:00:00","2021-12-16T00:00:00","2021-12-17T00:00:00","2021-12-18T00:00:00","2021-12-19T00:00:00","2021-12-20T00:00:00","2021-12-21T00:00:00","2021-12-22T00:00:00","2021-12-23T00:00:00","2021-12-26T00:00:00","2021-12-27T00:00:00","2021-12-28T00:00:00","2021-12-29T00:00:00","2021-12-30T00:00:00","2021-12-31T00:00:00","2022-01-01T00:00:00","2022-01-02T00:00:00","2022-01-03T00:00:00","2022-01-04T00:00:00","2022-01-05T00:00:00","2022-01-06T00:00:00","2022-01-07T00:00:00","2022-01-08T00:00:00","2022-01-09T00:00:00","2022-01-10T00:00:00","2022-01-11T00:00:00","2022-01-12T00:00:00","2022-01-14T00:00:00","2022-01-15T00:00:00","2022-01-16T00:00:00","2022-01-17T00:00:00","2022-01-19T00:00:00","2022-01-20T00:00:00","2022-01-21T00:00:00","2022-01-22T00:00:00","2022-01-23T ...

# %% [markdown]
# ### Hourly Data Interpolation

# %%
# Create raw and interpolated hourly datasets
print("Creating raw hourly dataset...")
ds_hourly_raw = Dataset(res="hourly")
ds_hourly_raw.create()
ds_hourly_raw.clean(plot=False)

print(f"\nRaw hourly dataset (after basic cleaning):")
print(f"Total records: {len(ds_hourly_raw.df)}")
print(f"Unique sensors: {ds_hourly_raw.df['id'].n_unique()}")

print("\nCreating interpolated hourly dataset...")
ds_hourly_interpolated = InterpolatedDataset(res="hourly")
ds_hourly_interpolated.create()
ds_hourly_interpolated.clean(plot=False)

print(f"\nInterpolated hourly dataset:")
print(f"Total records: {len(ds_hourly_interpolated.df)}")
print(f"Unique sensors/series: {ds_hourly_interpolated.df['id'].n_unique()}")
print(f"Records added: {len(ds_hourly_interpolated.df) - len(ds_hourly_raw.df)}")
# Out:
# Creating raw hourly dataset...
# 2026-04-21 22:44:24.618 | INFO     | src.energy_forecast.dataset:create:50 - Creating hourly dataset
# 2026-04-21 22:44:24.730 | INFO     | src.energy_forecast.dataset:create:55 - Number of rows: 870230
# 2026-04-21 22:44:24.793 | INFO     | src.energy_forecast.dataset:create:57 - Number of sensors: 61
# 2026-04-21 22:44:24.793 | INFO     | src.energy_forecast.dataset:clean:65 - Cleaning hourly dataset
# 2026-04-21 22:44:24.794 | INFO     | src.energy_forecast.dataset:clean:67 - Number of rows: 870230
# 2026-04-21 22:44:24.794 | INFO     | src.energy_forecast.dataset:clean:69 - Removing negative diff values
# 2026-04-21 22:44:24.796 | INFO     | src.energy_forecast.dataset:clean:71 - Number of rows after removing negative values: 870210
# 2026-04-21 22:44:24.797 | INFO     | src.energy_forecast.dataset:clean:73 - Filter connection error values
# 2026-04-21 22:44:39.564 | INFO     | src.energy_forecast.dataset:clean:76 - Number of rows after removing connection error values: 853488
# 2026-04-21 22:44:39.565 | INFO     | src.energy_forecast.dataset:clean:78 - Filtering outliers
# 2026-04-21 22:44:39.605 | INFO     | src.energy_forecast.dataset:clean:80 - Number of rows after filtering outliers: 823722
# 2026-04-21 22:44:39.605 | INFO     | src.energy_forecast.dataset:clean:82 - Filtering flat lines
# 2026-04-21 22:45:28.280 | INFO     | src.energy_forecast.dataset:clean:85 - Number of rows after filtering flat lines: 688766
# 2026-04-21 22:45:32.047 | INFO     | src.energy_forecast.utils.util:get_missing_dates:110 - Wrote information about missing dates to /home/marja/PycharmProjects/energy-forecast-wahl/reports/missing_dates_h.csv
# 2026-04-21 22:45:32.083 | INFO     | src.energy_forecast.dataset:clean:89 - Number of sensors after cleaning data: 61
# 2026-04-21 22:45:32.083 | SUCCESS  | src.energy_forecast.dataset:clean:90 - Number of rows after cleaning data: 688766
#
# Raw hourly dataset (after basic cleaning):
# Total records: 688766
# Unique sensors: 61
#
# Creating interpolated hourly dataset...
# 2026-04-21 22:45:32.105 | INFO     | src.energy_forecast.dataset:create:50 - Creating hourly dataset
# 2026-04-21 22:45:32.183 | INFO     | src.energy_forecast.dataset:create:55 - Number of rows: 870230
# 2026-04-21 22:45:32.235 | INFO     | src.energy_forecast.dataset:create:57 - Number of sensors: 61
# 2026-04-21 22:45:32.236 | INFO     | src.energy_forecast.dataset:clean:65 - Cleaning hourly dataset
# 2026-04-21 22:45:32.236 | INFO     | src.energy_forecast.dataset:clean:67 - Number of rows: 870230
# 2026-04-21 22:45:32.236 | INFO     | src.energy_forecast.dataset:clean:69 - Removing negative diff values
# 2026-04-21 22:45:32.239 | INFO     | src.energy_forecast.dataset:clean:71 - Number of rows after removing negative values: 870210
# 2026-04-21 22:45:32.240 | INFO     | src.energy_forecast.dataset:clean:73 - Filter connection error values
# 2026-04-21 22:45:46.744 | INFO     | src.energy_forecast.dataset:clean:76 - Number of rows after removing connection error values: 853488
# 2026-04-21 22:45:46.745 | INFO     | src.energy_forecast.dataset:clean:78 - Filtering outliers
# 2026-04-21 22:45:46.791 | INFO     | src.energy_forecast.dataset:clean:80 - Number of rows after filtering outliers: 823722
# 2026-04-21 22:45:46.791 | INFO     | src.energy_forecast.dataset:clean:82 - Filtering flat lines
# 2026-04-21 22:46:33.760 | INFO     | src.energy_forecast.dataset:clean:85 - Number of rows after filtering flat lines: 688766
# 2026-04-21 22:46:37.146 | INFO     | src.energy_forecast.utils.util:get_missing_dates:110 - Wrote information about missing dates to /home/marja/PycharmProjects/energy-forecast-wahl/reports/missing_dates_h.csv
# 2026-04-21 22:46:37.172 | INFO     | src.energy_forecast.dataset:clean:89 - Number of sensors after cleaning data: 61
# 2026-04-21 22:46:37.172 | SUCCESS  | src.energy_forecast.dataset:clean:90 - Number of rows after cleaning data: 688766
# 2026-04-21 22:46:37.174 | INFO     | src.energy_forecast.dataset:clean:238 - Split series with long series of missing values
# 2026-04-21 22:46:45.659 | INFO     | src.energy_forecast.dataset:clean:243 - Interpolating values
# 2026-04-21 22:47:15.956 | INFO     | src.energy_forecast.dataset:clean:246 - Remove negative consumption values
# 2026-04-21 22:47:16.007 | INFO     | src.energy_forecast.dataset:clean:249 - Split series with long series of missing values
# 2026-04-21 22:47:24.889 | INFO     | src.energy_forecast.dataset:clean:252 - Number of rows after interpolating: 834313
# 2026-04-21 22:47:24.922 | INFO     | src.energy_forecast.dataset:clean:260 - Saved series info to /home/marja/PycharmProjects/energy-forecast-wahl/reports/dataset_interpolate_hourly_24_series_info.csv
# 2026-04-21 22:47:24.922 | INFO     | src.energy_forecast.dataset:clean:261 - Number of series after splitting: 1127
#
# Interpolated hourly dataset:
# Total records: 834313
# Unique sensors/series: 1125
# Records added: 145547

# %%
# Select a sensor for hourly visualization
common_sensors_hourly = set(ds_hourly_raw.df['id'].unique()) & set(ds_hourly_interpolated.df['id'].unique())
sample_sensor_hourly = list(common_sensors_hourly)[0]

# Get a time window to visualize (e.g., 1 month)
df_h_before = ds_hourly_raw.df.filter(pl.col("id") == sample_sensor_hourly).sort("datetime")
df_h_after = ds_hourly_interpolated.df.filter(pl.col("id") == sample_sensor_hourly).sort("datetime")

# Take a 2-week window for clearer visualization
start_date = df_h_before['datetime'].min()
end_date = start_date + pl.duration(days=14)

df_h_before_window = df_h_before.filter(
    (pl.col("datetime") >= start_date) & (pl.col("datetime") <= end_date)
)
df_h_after_window = df_h_after.filter(
    (pl.col("datetime") >= start_date) & (pl.col("datetime") <= end_date)
)

print(f"Visualization window: {start_date} to {end_date}")
print(f"Before: {len(df_h_before_window)} records")
print(f"After: {len(df_h_after_window)} records")
# Out:
# Visualization window: 2022-01-24 13:00:00 to [(2022-01-24 13:00:00.strict_cast(Datetime(Microseconds, None))) + (14d.alias("duration"))]
# Before: 239 records
# After: 337 records

# %%
# Plot hourly data before and after
fig = make_subplots(
    rows=2, cols=1,
    subplot_titles=("Before Interpolation (2-week window)", "After Interpolation (2-week window)"),
    vertical_spacing=0.12
)

# Before interpolation
fig.add_trace(
    go.Scatter(x=df_h_before_window['datetime'], y=df_h_before_window['diff'], 
               mode='lines+markers', name='Before',
               line=dict(color='blue')),
    row=1, col=1
)

# After interpolation
fig.add_trace(
    go.Scatter(x=df_h_after_window['datetime'], y=df_h_after_window['diff'], 
               mode='lines+markers', name='After',
               line=dict(color='green')),
    row=2, col=1
)

fig.update_xaxes(title_text="Date", row=2, col=1)
fig.update_yaxes(title_text="Consumption (diff)", row=1, col=1)
fig.update_yaxes(title_text="Consumption (diff)", row=2, col=1)

fig.update_layout(
    title_text="Hourly Data Interpolation: Example Sensor",
    template="plotly",
    height=800,
    showlegend=True
)

fig.show()
fig.write_image(FIGURES_DIR / "interpolation_hourly_before_after.png", width=1200, height=800, scale=2)
# Out:
# <div>                            <div id="c25af6b9-0f5d-4f1e-94a4-b4b649081311" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c25af6b9-0f5d-4f1e-94a4-b4b649081311")) {                    Plotly.newPlot(                        "c25af6b9-0f5d-4f1e-94a4-b4b649081311",                        [{"line":{"color":"blue"},"mode":"lines+markers","name":"Before","x":["2022-01-24T13:00:00","2022-01-24T14:00:00","2022-01-24T15:00:00","2022-01-24T16:00:00","2022-01-24T17:00:00","2022-01-24T18:00:00","2022-01-24T19:00:00","2022-01-24T20:00:00","2022-01-24T21:00:00","2022-01-24T22:00:00","2022-01-24T23:00:00","2022-01-25T00:00:00","2022-01-25T01:00:00","2022-01-25T03:00:00","2022-01-25T05:00:00","2022-01-25T07:00:00","2022-01-25T10:00:00","2022-01-25T14:00:00","2022-01-25T15:00:00","2022-01-25T16:00:00","2022-01-25T17:00:00","2022-01-25T18:00:00","2022-01-25T19:00:00","2022-01-25T20:00:00","2022-01-25T21:00:00","2022-01-25T22:00:00","2022-01-25T23:00:00","2022-01-26T00:00:00","2022-01-26T01:00:00","2022-01-26T03:00:00","2022-01-26T12:00:00","2022-01-26T13:00:00","2022-01-26T15:00:00","2022-01-26T16:00:00","2022-01-26T17:00:00","2022-01-26T18:00:00","2022-01-26T19:00:00","2022-01-26T20:00:00","2022-01-27T13:00:00","2022-01-27T14:00:00","2022-01-27T15:00:00","2022-01-27T16:00:00","2022-01-27T17:00:00","2022-01-27T18:00:00","2022-01-27T19:00:00","2022-01-27T20:00:00","2022-01-27T21:00:00","2022-01-27T22:00:00","2022-01-27T23:00:00","2022-01-28T00:00:00","2022-01-28T01:00:00","2022-01-28T03:00:00","2022-01-28T08:00:00","2022-01-28T09:00:00","2022-01-28T10:00:00","2022-01-28T11:00:00","2022-01-28T12:00:00","2022-01-28T13:00:00","2022-01-28T14:00:00","2022-01-28T15:00:00","2022-01-28T16:00:00","2022-01-28T17:00:00","2022-01-28T18:00:00","2022-01-28T19:00:00","2022-01-28T20:00:00","2022-01-28T21:00:00","2022-01-28T22:00:00","2022-01-28T23:00:00","2022-01-29T00:00:00","2022-01-29T01:00:00","2022-01-29T02:00:00","2022-01-29T03:00:00","2022-01-29T04:00:00","2022-01-29T06:00:00","2022-01-29T07:00:00","2022-01-29T08:00:00","2022-01-29T09:00:00","2022-01-29T10:00:00","2022-01-29T11:00:00","2022-01-29T12:00:00","2022-01-29T13:00:00","2022-01-29T14:00:00","2022-01-29T15:00:00","2022-01-29T16:00:00","2022-01-29T17:00:00","2022-01-29T18:00:00","2022-01-29T19:00:00","2022-01-29T20:00:00","2022-01-29T21:00:00","2022-01-29T22:00:00","2022-01-29T23:00:00","2022-01-30T00:00:00","2022-01-30T01:00:00","2022-01-30T02:00:00","2022-01-30T03:00:00","2022-01-30T04:00:00","2022-01-30T05:00:00","2022-01-30T06:00:00","2022-01-30T08:00:00","2022-01-30T09:00:00","2022-01-30T10:00:00","2022-01-30T11:00:00","2022-01-30T12:00:00","2022-01-30T13:00:00","2022-01-30T14:00:00","2022-01-30T15:00:00","2022-01-30T16:00:00","2022-01-30T17:00:00","2022-01-30T18:00:00","2022-01-30T19:00:00","2022-01-30T20:00:00","2022-01-30T21:00:00","2022-01-30T22:00:00","2022-01-30T23:00:00","2022-01-31T00:00:00","2022-01-31T03:00:00","2022-01-31T04:00:00","2022-01-31T05:00:00","2022-01-31T13:00:00","2022-01-31T14:00:00","2022-01-31T16:00:00","2022-01-31T17:00:00","2022-01-31T18:00:00","2022-01-31T19:00:00","2022-01-31T20:00:00","2022-01-31T21:00:00","2022-01-31T22:00:00","2022-01-31T23:00:00","2022-02-01T00:00:00","2022-02-01T01:00:00","2022-02-01T03:00:00","2022-02-01T04:00:00","2022-02-01T13:00:00","2022-02-01T14:00:00","2022-02-01T15:00:00","2022-02-01T16:00:00","2022-02-01T17:00:00","2022-02-01T18:00:00","2022-02-01T19:00:00","2022-02-01T20:00:00","2022-02-01T21:00:00","2022-02-01T22:00:00","2022-02-01T23:00:00","2022-02-02T00:00:00","2022-02-02T01:00:00","2022-02-02T03:00:00","2022-02-02T05:00:00","2022-02-02T07:00:00","2022-02-02T08:00:00","2022-02-02T11:00:00","2022-02-02T13:00:00","2022-02-02T14:00:00","2022-02-02T15:00:00","2022-02-02T16:00:00","2022-02-02T ...

# %% [markdown]
# ## Summary
#
# This notebook demonstrated:
# 1. **Time span analysis** showing the temporal coverage of sensors before and after train/test/val splitting
# 2. **Data splitting** process that filters out short series
# 3. **Outlier detection** using the IQR method
# 4. **Data interpolation** process that fills missing timestamps in the time series
#
# Key findings:
# - The train/test/val split removes sensors with insufficient data
# - Interpolation significantly increases the number of records by filling gaps
# - The cleaning process (outlier removal, negative value filtering) ensures data quality before interpolation
